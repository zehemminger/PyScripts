# %%
base_path = '/bigstore/binfo/mouse/Brain/Sequencing/Allen_10X_SmartSeqTypes/'
import os
loadings_fname= [i for i in os.listdir(base_path) if '_dpnmf_loadings.npy' in i]

# %%
import numpy as np
loadings_dict = {}
for fname in loadings_fname:
    loadings_dict[fname.split('_')[1]] = np.load(os.path.join(base_path,fname))

# %%
import sys
import seaborn as sns
import matplotlib.pyplot as plt
sys.setrecursionlimit(10000)

# %%
mu = '1'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
orthoganality.shape
# Out:
# (24, 24)

# %%
mu = '1'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
g = sns.clustermap(np.log10(orthoganality+1),cmap="Reds")
g.fig.suptitle('Mu = '+mu)
g
plt.show()

# %%
mu = '5'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
g = sns.clustermap(np.log10(orthoganality+1),cmap="Reds")
g.fig.suptitle('Mu = '+mu)
g
plt.show()

# %%
mu = '10'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
g = sns.clustermap(np.log10(orthoganality+1),cmap="Reds")
g.fig.suptitle('Mu = '+mu)
g
plt.show()

# %%
mu = '20'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
g = sns.clustermap(np.log10(orthoganality+1),cmap="Reds")
g.fig.suptitle('Mu = '+mu)
g
plt.show()

# %%
mu = '50'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
g = sns.clustermap(np.log10(orthoganality+1),cmap="Reds")
g.fig.suptitle('Mu = '+mu)
g
plt.show()

# %%
mu = '100'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
g = sns.clustermap(np.log10(orthoganality+1),cmap="Reds")
g.fig.suptitle('Mu = '+mu)
g
plt.show()

# %%
mu = '500'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
g = sns.clustermap(np.log10(orthoganality+1),cmap="Reds")
g.fig.suptitle('Mu = '+mu)
g
plt.show()

# %%
mu = '1000'
loading = loadings_dict[mu]
orthoganality = np.dot(loading,loading.T)
g = sns.clustermap(np.log10(orthoganality+1),cmap="Reds")
g.fig.suptitle('Mu = '+mu)
g
plt.show()
