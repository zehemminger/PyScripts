# %%
import csv
from scipy import sparse
from tqdm import tqdm
import os
import pandas as pd
import numpy as np
base_path = '/bigstore/binfo/mouse/Brain/Sequencing/Allen_10X_SmartSeqTypes/'
genes = np.array(list(pd.read_csv(os.path.join(base_path,'gene_name.csv'),index_col=0)['x']))
cells = np.array(list(pd.read_csv(os.path.join(base_path,'sample_name.csv'),index_col=0)['x']))
metadata = pd.read_csv(os.path.join(base_path,'metadata.csv'),index_col=0).loc[cells]
counts = np.load(os.path.join(base_path,'matrix.npy'))
cell_size = np.sum(counts,axis=1)/(5*(10**5))
celltypes = np.array(metadata['cell_type_alias_label'].unique())
celltypes = np.array([i for i in celltypes if isinstance(i,str)])
normcounts = np.stack([(counts[i,:]/cell_size[i]).astype('uint16') for i in tqdm(range(counts.shape[0]),total=counts.shape[0])])
metadata['counts_loc'] = range(normcounts.shape[0]) 
del counts
# Out:
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# 100%|██████████| 1093036/1093036 [03:32<00:00, 5153.78it/s]

# %%
import importlib
cword_config = 'seqfish_config_tbi_v4'
config = importlib.import_module(cword_config)
tbi_genes = config.gids

# %%
"""
Find 100 genes that seperate all high level types well
"""

# %%
high_level_celltypes_dict = {i:i.split('_')[1] for i in celltypes if i!=np.nan}
high_level_celltypes_dict[np.nan] = 'nan'
high_level_labels = [high_level_celltypes_dict[i] for i in metadata['cell_type_alias_label']]
metadata['high_level_label'] = high_level_labels
metadata = metadata[metadata['high_level_label']!='nan']
high_level_celltypes = np.unique(metadata['high_level_label'])
high_level_celltypes=high_level_celltypes
high_level_celltypes
# Out:
# array(['Astro', 'CA1', 'CA1-ProS', 'CA2-IG-FC', 'CA3', 'CR', 'CT SUB',
#        'DG', 'Endo', 'L2 IT ENTl', 'L2 IT ENTm', 'L2 IT HATA',
#        'L2 IT PAR', 'L2 IT ProS', 'L2 IT RSP-ACA', 'L2 IT RSPv',
#        'L2/3 IT APr', 'L2/3 IT CTX', 'L2/3 IT ENTl', 'L2/3 IT PPP',
#        'L2/3 IT TPE', 'L3 IT ENTl', 'L3 IT ENTm', 'L3 RSP-ACA',
#        'L4/5 IT CTX', 'L4/5 IT TPE-ENT', 'L5 IT CTX', 'L5 IT TPE-ENT',
#        'L5 NP CTX', 'L5 PPP', 'L5 PT CTX', 'L5 PT RSP-ACA', 'L5/6 IT CTX',
#        'L6 CT CTX', 'L6 CT ENTm', 'L6 Car3', 'L6 IT CTX', 'L6 IT ENTl',
#        'L6 IT RHP', 'L6 NP CT CTX', 'L6b CTX', 'L6b RHP', 'L6b/CT ENT',
#        'Lamp5', 'Lamp5 Lhx6', 'Meis2', 'Micro', 'NP PPP', 'NP SUB',
#        'Ndnf HPF', 'OPC', 'Oligo', 'PVM', 'Pax6', 'Peri', 'ProS', 'Pvalb',
#        'Pvalb Vipr2', 'SMC', 'SUB', 'SUB-ProS', 'Sncg', 'Sst',
#        'Sst Chodl', 'V3d', 'VLMC', 'Vip'], dtype=object)

# %%
unqtypes = np.unique(metadata[metadata['region_label']=='HIP']['cell_type_alias_label'])
Gmu = np.zeros((len(genes),len(unqtypes)))
Gstd = np.zeros((len(genes),len(unqtypes)))
for i,ct in tqdm(enumerate(unqtypes),total=len(unqtypes)):
    ct_indexes = list(metadata[(metadata['region_label']=='HIP')&(metadata['cell_type_alias_label']==ct)]['counts_loc'])
    if len(ct_indexes)>1:
        Gmu[:,i] = np.mean(normcounts[ct_indexes,:],axis=0)
        Gstd[:,i] = np.std(normcounts[ct_indexes,:],axis=0)
    else:
        Gmu[:,i] = normcounts[ct_indexes,:]
        Gstd[:,i] = normcounts[ct_indexes,:]
Gmu_max = np.max(Gmu,axis=1)
Gsep = np.array([np.nanmean(np.abs(Gmu[i,:,None]-Gmu[i,None,:])) for i in tqdm(range(Gmu.shape[0]))])
Gstd_max = Gstd[range(0,Gstd.shape[0]),np.argmax(Gmu,axis=1)]
# Out:
# ...
# 100%|██████████| 31053/31053 [00:09<00:00, 3201.57it/s]

# %%
import matplotlib.pyplot as plt
m_min = np.log10(10+1)
m_max = np.log10(1500+1)
m_sep_min = np.log10(0.5+1)
m_sep_max = np.log10(30+1)
# X = Gmu_max
# Y = Gsep
# Y = mx+b
# Slope = (y2-y1)(x2-x1)
# Intercept = Y-mx
sep_slope = (m_sep_max-m_sep_min)/(m_max-m_min)
sep_intercept = m_sep_min-(m_min*sep_slope)
mu_mask = (Gmu_max>10)&(Gmu_max<1500)
sep_mask = (np.log10(Gsep+1)>((np.log10(Gmu_max+1)*sep_slope)+sep_intercept))
print(len(genes[mu_mask&sep_mask]))
x = np.linspace(m_min,m_max,num=10)
y = (x*sep_slope)+sep_intercept
plt.figure(figsize=[10,10])
plt.plot(x,y,c='b')
plt.scatter(np.log10(Gmu_max[(mu_mask==False)]+1),np.log10(Gsep[(mu_mask==False)]+1),s=1,alpha=0.1)
plt.scatter(np.log10(Gmu_max[(mu_mask)&(sep_mask==False)]+1),np.log10(Gsep[(mu_mask)&(sep_mask==False)]+1),c='g',s=1,alpha=0.1)
plt.scatter(np.log10(Gmu_max[(mu_mask)&(sep_mask)]+1),np.log10(Gsep[(mu_mask)&(sep_mask)]+1),s=1,c='r',alpha=0.1)
plt.scatter(np.log10(Gmu_max[np.isin(genes,tbi_genes)]+1),np.log10(Gsep[np.isin(genes,tbi_genes)]+1),s=10,c='K',alpha=1)
# plt.plot([m_min,m_max],[m_sep_min,m_sep_max],c='g')
plt.plot([m_min,m_min],[m_sep_min,4],c='b')
plt.plot([m_max,m_max],[m_sep_max,4],c='b')
plt.xlabel('Gmu_max')
plt.ylabel('Gsep')
plt.show()
# Out:
# 12864

# %%
import matplotlib.pyplot as plt
m_min = np.log10(10+1)
m_max = np.log10(1500+1)
m_std_min = np.log10(50+1)
m_std_max = np.log10(400+1)
std_slope = (m_std_max-m_std_min)/(m_max-m_min)
std_intercept = m_std_min-(m_min*std_slope)
std_mask = (np.log10(Gstd_max+1)<(np.log10(Gmu_max+1)*std_slope)+std_intercept)
print(len(genes[mu_mask&std_mask&sep_mask]))
x = np.linspace(m_min,m_max,num=10)
y = (x*std_slope)+std_intercept
plt.figure(figsize=[10,10])
plt.plot(x,y,c='b')
plt.plot([m_min,m_min],[m_std_min,0],c='b')
plt.plot([m_max,m_max],[m_std_max,0],c='b')
plt.scatter(np.log10(Gmu_max[mu_mask==False]+1),np.log10(Gstd_max[mu_mask==False]+1),s=1,alpha=0.1)
plt.scatter(np.log10(Gmu_max[(mu_mask)&(std_mask==False)&(sep_mask==False)]+1),np.log10(Gstd_max[(mu_mask)&(std_mask==False)&(sep_mask==False)]+1),c='k',s=1,alpha=0.1)
plt.scatter(np.log10(Gmu_max[(mu_mask)&(std_mask==False)&(sep_mask)]+1),np.log10(Gstd_max[(mu_mask)&(std_mask==False)&(sep_mask)]+1),s=1,alpha=0.1,c='g')
plt.scatter(np.log10(Gmu_max[(mu_mask)&(std_mask)&(sep_mask)]+1),np.log10(Gstd_max[(mu_mask)&(std_mask)&(sep_mask)]+1),s=1,c='r',alpha=0.1)
plt.scatter(np.log10(Gmu_max[np.isin(genes,tbi_genes)]+1),np.log10(Gstd_max[np.isin(genes,tbi_genes)]+1),s=10,c='K',alpha=1)
plt.xlabel('Gmu_max')
plt.ylabel('Gstd_max')
plt.show()
# Out:
# 7572

# %%
filtered_counts = normcounts[:,((Gmu_max>10)&(Gmu_max<1500))]#&std_mask&sep_mask)]
filtered_genes = genes[((Gmu_max>10)&(Gmu_max<1500))]
filtered_counts.shape
# Out:
# (1093036, 17283)

# %%
ct_indexes = np.array(list(metadata[(metadata['region_label']=='HIP')]['counts_loc']))
hip_filtered_counts = filtered_counts[ct_indexes,:]
hip_labels = np.array(list(metadata[(metadata['region_label']=='HIP')]['cell_type_alias_label']))

# %%
unique_labels = np.unique(true)
label_converter = {label:i for i,label in enumerate(unique_labels)}
true_converted = np.array([label_converter[i] for i in true])
predicted_converted = np.array([label_converter[i] for i in predicted])

# %%
def show_confusion_matrix(true,predicted):
    unique_labels = np.unique(true)
    label_converter = {label:i for i,label in enumerate(unique_labels)}
    true_converted = np.array([label_converter[i] for i in true])
    predicted_converted = np.array([label_converter[i] for i in predicted])
    confmat = np.zeros((len(unique_labels),len(unique_labels)))
    for i,it in enumerate(unique_labels):
        it_converted = label_converter[it]
        for j,jt in enumerate(unique_labels):
            jt_converted = label_converter[jt]
            confmat[i,j] = np.sum((true_converted==it_converted)&(predicted_converted==jt_converted))/np.sum((true_converted==it_converted))
    confmat = pd.DataFrame(confmat,index=unique_labels,columns=unique_labels)
    plt.figure(figsize=[10,10])
    sns.heatmap(confmat,cmap='Reds')
    plt.show()

# %%
# Generate test train set 
ncells = hip_filtered_counts.shape[0]
test_indexes = np.random.choice(np.array(range(ncells)),int(0.25*ncells))
train_indexes = np.array(range(ncells))[(np.isin(np.array(range(ncells)),test_indexes)==False)]
test_counts = hip_filtered_counts[test_indexes,:]
train_counts = hip_filtered_counts[train_indexes,:]
test_labels = hip_labels[test_indexes]
train_labels = hip_labels[train_indexes]
print('test:',test_counts.shape,'train:',train_counts.shape)
# Out:
# test: (19356, 17283) train: (60278, 17283)

# %%
# check TBI Genes
mask = np.isin(genes,tbi_genes)
filtered_genes = genes[((Gmu_max>10)&(Gmu_max<1500))]
tbi_filtered_genes = filtered_genes[np.isin(filtered_genes,tbi_genes)]
tbi_test_counts = test_counts[:,np.isin(filtered_genes,tbi_genes)]
tbi_train_counts = train_counts[:,np.isin(filtered_genes,tbi_genes)]

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(tbi_train_counts,train_labels)
predicted = lda.predict(tbi_test_counts)
true = test_labels.copy()
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
true_red = np.array([i.split('_')[1] for i in true])
predicted_red = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted_red.shape[0]) if predicted_red[i]==true_red[i]])/predicted_red.shape[0])
show_confusion_matrix(true,predicted)
show_confusion_matrix(true_red,predicted_red)
# Out:
# 0.8360198388096715
# 1.0

# %%
# Use RFE to find 150 genes
from sklearn.feature_selection import RFE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
rfe = RFE(lda, 150,verbose=1,step=0.3)
rfe = rfe.fit(train_counts,train_labels)
lda.fit(train_counts[:,rfe.support_],train_labels)
predicted = lda.predict(test_counts[:,rfe.support_])
true = test_labels.copy()
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
true_red = np.array([i.split('_')[1] for i in true])
predicted_red = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted_red.shape[0]) if predicted_red[i]==true_red[i]])/predicted_red.shape[0])
show_confusion_matrix(true,predicted)
show_confusion_matrix(true_red,predicted_red)
# Out:
# Fitting estimator with 17283 features.

# %%
# Low variance
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
sel.fit_transform(train_counts)
# Mutual information
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
X_new = SelectKBest(mutual_info_classif, k=150).fit_transform(train_counts,train_labels)

# %%
# hip_unqtypes_high = np.array(['DG','CA1','Astro','Micro','CA3','Oligo','Sst','Endo','SMC','Vip','CA1-ProS','Pvalb','CA2-IG-FC', 'Pvalb Vipr2','OPC','Sst Chodl'])
hip_unqtypes_high = np.array([i for i in np.unique(metadata[metadata['region_label']=='HIP']['high_level_label']) if i!='nan'])
hip_unqtypes_low = np.unique(metadata[(metadata['region_label']=='HIP')&(metadata['high_level_label'].isin(hip_unqtypes_high))]['cell_type_alias_label'])
hip_unqtypes_low
# Out:
# array(['100_Sst', '101_Sst', '103_Sst', '107_Pvalb', '10_Lamp5',
#        '111_Pvalb', '113_Pvalb', '115_Pvalb', '116_Pvalb',
#        '119_Pvalb Vipr2', '11_Lamp5', '120_DG', '121_DG', '122_DG',
#        '123_DG', '124_DG', '125_DG', '12_Lamp5', '132_L2/3 IT PPP',
#        '133_L2/3 IT PPP', '134_L2/3 IT PPP', '13_Lamp5', '14_Lamp5',
#        '155_L2 IT ProS', '156_L2 IT ProS', '157_L2 IT HATA', '15_Lamp5',
#        '165_L2/3 IT ENTl', '167_L2/3 IT ENTl', '168_L2/3 IT ENTl',
#        '16_Lamp5', '173_L2/3 IT ENTl', '176_L2/3 IT CTX',
#        '197_L4/5 IT CTX', '1_CR', '20_Ndnf HPF', '211_L5 IT TPE-ENT',
#        '21_Ndnf HPF', '221_L6 IT CTX', '22_Ndnf HPF', '23_Ndnf HPF',
#        '24_Ndnf HPF', '252_L5 PT CTX', '25_Sncg', '263_SUB', '264_SUB',
#        '266_SUB-ProS', '267_SUB-ProS', '268_ProS', '269_ProS', '26_Sncg',
#        '270_ProS', '271_ProS', '272_ProS', '273_CA1-ProS', '274_CA1-ProS',
#        '275_CA1-ProS', '276_CA1-ProS', '277_CA1-ProS', '278_CA1-ProS',
# ...

# %%
# Need to figure out which genes are best for seperating high level cell types
# Class Balance
"""
For only Hippocampus Cells
"""
unqtypes = np.unique(metadata[metadata['region_label']=='HIP']['cell_type_alias_label'])
n = 100
class_balanced = np.empty((len(unqtypes)*n,filtered_counts.shape[1]))
balanced_labels = np.empty((len(unqtypes)*n)).astype(str)
for i,ct in tqdm(enumerate(unqtypes),total=len(unqtypes)):
    start = i*n
    end = (i+1)*n
    ct_indexes =list(metadata[(metadata['region_label']=='HIP')&(metadata['cell_type_alias_label']==ct)]['counts_loc'])
    if len(ct_indexes)>n:
        ct_indexes = np.random.choice(ct_indexes,n,replace=False)
    else:
        ct_indexes = np.random.choice(ct_indexes,n,replace=True)
    balanced_labels[start:end] = ct
    class_balanced[start:end,:] = filtered_counts[ct_indexes,:]
# Out:
# 100%|██████████| 166/166 [00:42<00:00,  3.87it/s]

# %%
ct_indexes =list(metadata[(metadata['region_label']=='HIP')&(metadata['high_level_label'].isin(hip_unqtypes_high))]['counts_loc'])
hip_filtered_counts = filtered_counts[ct_indexes,:]
hip_labels = list(metadata[(metadata['region_label']=='HIP')&(metadata['high_level_label'].isin(hip_unqtypes_high))]['cell_type_alias_label'].astype(str))
hip_filtered_counts.shape
# Out:
# (73857, 11419)

# %%
from sklearn.feature_selection import RFE
lda = LinearDiscriminantAnalysis()
rfe = RFE(lda, 200,verbose=1,step=0.3)
rfe = rfe.fit(hip_filtered_counts, [i.split('_')[1] for i in hip_labels])
print(rfe.support_)
print(rfe.ranking_)
lda.fit(hip_filtered_counts[:,rfe.support_],hip_labels)
predicted = lda.predict(hip_filtered_counts[:,rfe.support_])
true = hip_labels.copy()
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
from collections import Counter
true = np.array(true)
predicted = np.array(predicted)
types = np.unique(true)
confmat = np.zeros((len(types),len(types)))
for i,it in enumerate(types):
    for j,jt in enumerate(types):
        confmat[i,j] = np.sum((true==it)&(predicted==jt))/np.sum((true==it))
plt.figure(figsize=[10,10])
sns.heatmap(confmat,cmap='Reds')
plt.show()
# Out:
# Fitting estimator with 11419 features.
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# Fitting estimator with 7994 features.
# Fitting estimator with 4569 features.
# Fitting estimator with 1144 features.
# [False False False ... False False False]
# [5 3 4 ... 3 3 5]
# 0.7097770015029042

# %%
# median = np.median(class_balanced,axis=0)
# std = np.std(class_balanced,axis=0)
# normalized_counts = np.divide(np.subtract(class_balanced,median),std).astype(int)
median = np.median(hip_filtered_counts,axis=0)
std = np.std(hip_filtered_counts,axis=0)
normalized_counts = np.divide(np.subtract(hip_filtered_counts,median),std).astype(int)
# Out:
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
pca = PCA(n_components=50)
pca_counts = pca.fit_transform(normalized_counts)
import umap
reducer = umap.UMAP()
embedding = reducer.fit_transform(pca_counts)
# embedding = TSNE(n_components=2).fit_transform(pca_counts)
# embedding.shape

# %%
import matplotlib.pyplot as plt
balanced_labels_reduced = [i.split('_')[1] for i in hip_labels]
plt.figure(figsize=[10,10])
reduced_unqtypes = np.unique(balanced_labels_reduced)
for ct in reduced_unqtypes:
    mask = np.array(balanced_labels_reduced)==ct
    plt.scatter(embedding[mask,0],embedding[mask,1],label=ct,s=1)
plt.legend()
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
nbclass = GaussianNB()
nbclass.fit(class_balanced, [i.split('_')[1] for i in balanced_labels])
predicted = nbclass.predict(filtered_counts)
true = labels
true = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-246-e55e54d46cc8> in <module>
#       2 nbclass = GaussianNB()
#       3 nbclass.fit(class_balanced, [i.split('_')[1] for i in balanced_labels])
# ----> 4 predicted = nbclass.predict(filtered_counts)
#       5 true = labels
#       6 true = np.array([i.split('_')[1] for i in true])
#
# ~/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/naive_bayes.py in predict(self, X)
#      64             Predicted target values for X
#      65         """
# ---> 66         jll = self._joint_log_likelihood(X)
#      67         return self.classes_[np.argmax(jll, axis=1)]
#      68
#
# ~/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/naive_bayes.py in _joint_log_likelihood(self, X)
#     436             n_ij = - 0.5 * np.sum(np.log(2. * np.pi * self.sigma_[i, :]))
# ...

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(class_balanced, [i.split('_')[1] for i in balanced_labels])
predicted = lda.predict(hip_filtered_counts)
true = hip_labels.copy()
true = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# 0.9105975059913075

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(hip_filtered_counts, [i.split('_')[1] for i in hip_labels])
predicted = lda.predict(hip_filtered_counts)
true = hip_labels.copy()
true = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# 0.9991334606063068

# %%
from sklearn.feature_selection import RFE
lda = LinearDiscriminantAnalysis()
rfe = RFE(lda, 200,verbose=1,step=0.3)
rfe = rfe.fit(hip_filtered_counts, [i.split('_')[1] for i in hip_labels])
print(rfe.support_)
print(rfe.ranking_)
lda.fit(hip_filtered_counts[:,rfe.support_],[i.split('_')[1] for i in hip_labels])
predicted = lda.predict(hip_filtered_counts[:,rfe.support_])
true = hip_labels.copy()
true = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# Fitting estimator with 7528 features.
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# Fitting estimator with 5270 features.
# Fitting estimator with 3012 features.
# Fitting estimator with 754 features.
# [False False False ... False False False]
# [4 3 5 ... 4 4 4]
# 0.7890382766697808

# %%
import importlib
cword_config = 'seqfish_config_tbi_v4'
config = importlib.import_module(cword_config)
tbi_genes = config.gids

# %%
mask = np.isin(genes,tbi_genes)
filtered_counts = normcounts[:,mask]
ct_indexes =list(metadata[(metadata['region_label']=='HIP')&(metadata['high_level_label'].isin(hip_unqtypes_high))]['counts_loc'])
hip_filtered_counts = filtered_counts[ct_indexes,:]
hip_labels = list(metadata[(metadata['region_label']=='HIP')&(metadata['high_level_label'].isin(hip_unqtypes_high))]['cell_type_alias_label'].astype(str))
print(hip_filtered_counts.shape)

lda.fit(hip_filtered_counts,[i.split('_')[1] for i in hip_labels])
predicted = lda.predict(hip_filtered_counts)
true = hip_labels.copy()
true = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# (73857, 169)
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# 0.9935415735813803

# %%
from collections import Counter
types = np.unique(true)
confmat = np.zeros((len(types),len(types)))
for i,it in enumerate(types):
    for j,jt in enumerate(types):
        confmat[i,j] = np.sum((true==it)&(predicted==jt))/np.sum((true==it))
plt.figure(figsize=[10,10])
sns.heatmap(confmat,cmap='Reds')
plt.show()

# %%
lda.fit(hip_filtered_counts,hip_labels)
predicted = lda.predict(hip_filtered_counts)
true = hip_labels.copy()
# true = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# 0.8681912344124457

# %%
from collections import Counter
true = np.array(true)
predicted = np.array(predicted)
types = np.unique(true)
confmat = np.zeros((len(types),len(types)))
for i,it in enumerate(types):
    for j,jt in enumerate(types):
        confmat[i,j] = np.sum((true==it)&(predicted==jt))/np.sum((true==it))
plt.figure(figsize=[10,10])
sns.heatmap(confmat,cmap='Reds')
plt.show()

# %%
"""
A1- Peppers
A2- Letuce
A3- Spinach
A4- Basil
A5- Cilantro
A6- Scallions
A7- Oregano
B1- Kale
B2- Parsley
B3- Dill
B4- Chives
B5- Celery
B6- Broccoli
B7- Cherry Tomatoe
"""
# Out:
# '\nA1- Peppers\nA2- Letuce\nA3- Spinach\nA4- Basil\nA5- Cilantro\nA6- Scallions\nA7- Oregano\nB1- Kale\nB2- Parsley\nB3- Dill\nB4- Chives\nB5- Celery\nB6- Broccoli\nB7- Cherry Tomatoe\n\n'

# %%
class_balanced.shape
# Out:
# (37700, 2783)

# %%
from sklearn.feature_selection import RFE
lda = LinearDiscriminantAnalysis(solver='lsqr')
rfe = RFE(lda, 200,verbose=1,step=0.1)
rfe = rfe.fit(class_balanced, [i.split('_')[1] for i in balanced_labels])
print(rfe.support_)
print(rfe.ranking_)
lda.fit(class_balanced[:,rfe.support_],[i.split('_')[1] for i in balanced_labels])
predicted = lda.predict(filtered_counts[:,rfe.support_])
true = labels.copy()
true = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# true = np.array([i.split('_')[1] for i in true])
# predicted = np.array([i.split('_')[1] for i in predicted])
# print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# Fitting estimator with 2783 features.
# Fitting estimator with 2505 features.
# Fitting estimator with 2227 features.
# Fitting estimator with 1949 features.
# Fitting estimator with 1671 features.
# Fitting estimator with 1393 features.
# Fitting estimator with 1115 features.
# Fitting estimator with 837 features.
# Fitting estimator with 559 features.
# Fitting estimator with 281 features.
# [False False False ... False False False]
# [ 7  6  9 ...  3  7 10]
# 0.4363378699329208

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
dectree = DecisionTreeClassifier(criterion='gini')
rfe = RFE(dectree, 200,verbose=1,step=0.3)
rfe = rfe.fit(class_balanced,balanced_labels)
print(rfe.support_)
print(rfe.ranking_)
dectree.fit(class_balanced[:,rfe.support_],balanced_labels)
predicted = dectree.predict(filtered_counts[:,rfe.support_])
true = labels.copy()
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
true = np.array([i.split('_')[1] for i in true])
predicted = np.array([i.split('_')[1] for i in predicted])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# Fitting estimator with 2783 features.
# Fitting estimator with 1949 features.
# Fitting estimator with 1115 features.
# Fitting estimator with 281 features.
# [False False False ... False False False]
# [5 4 5 ... 3 3 5]
# 0.06372708675652038
# 0.20143343860586477

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
# from sklearn.linear_model import LogisticRegression
# nbclass = GaussianNB()
# logreg = LogisticRegression(solver='lbfgs',multi_class='multinomial',max_iter=100)
dectree = DecisionTreeClassifier(criterion='gini',min_samples_leaf=10)
rfe = RFE(dectree, 200,verbose=1,step=0.3)
rfe = rfe.fit(class_balanced, balanced_labels_reduced)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# Fitting estimator with 2783 features.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-236-a4189c2e703a> in <module>
#      11 # dectree = DecisionTreeClassifier(criterion='gini',min_samples_leaf=10)
#      12 rfe = RFE(nbclass, 200,verbose=1,step=0.3)
# ---> 13 rfe = rfe.fit(class_balanced, balanced_labels_reduced)
#      14 print(rfe.support_)
#      15 print(rfe.ranking_)
#
# ~/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/feature_selection/rfe.py in fit(self, X, y)
#     138             The target values.
#     139         """
# --> 140         return self._fit(X, y)
#     141
#     142     def _fit(self, X, y, step_score=None):
#
# ~/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/sklearn/feature_selection/rfe.py in _fit(self, X, y, step_score)
#     185                 coefs = getattr(estimator, 'feature_importances_', None)
# ...

# %%
dectree_genes = genes[(mu_mask&std_mask&sep_mask)][rfe.support_]
dectree_mask = np.isin(genes,dectree_genes)
dout = dectree.fit(class_balanced[:,rfe.support_],balanced_labels_reduced)
predicted = dout.predict(filtered_counts[:,rfe.support_])
true = labels
true = np.array([i.split('_')[1] for i in true])
print(len([i for i in range(predicted.shape[0]) if predicted[i]==true[i]])/predicted.shape[0])
# Out:
# 0.36975360372393956

# %%
shuffled = true.copy()
np.random.shuffle(shuffled)
print(len([i for i in range(shuffled.shape[0]) if shuffled[i]==true[i]])/shuffled.shape[0])
# Out:
# 0.0962100058918462

# %%
from collections import Counter
types = np.unique(true)
confmat = np.zeros((len(types),len(types)))
for i,it in enumerate(types):
    for j,jt in enumerate(types):
        confmat[i,j] = np.sum((true==it)&(predicted==jt))/np.sum((true==it))
plt.figure(figsize=[10,10])
sns.heatmap(confmat,cmap='Reds')
plt.show()

# %%
normalized_counts.shape
# Out:
# (37700, 2783)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=50)
pca_counts = pca.fit_transform(normalized_counts[:,rfe.support_])
import umap
reducer = umap.UMAP()
embedding = reducer.fit_transform(pca_counts)
import matplotlib.pyplot as plt
balanced_labels_reduced = [i.split('_')[0] for i in balanced_labels]
plt.figure(figsize=[10,10])
reduced_unqtypes = np.unique(balanced_labels_reduced)
for ct in reduced_unqtypes:
    mask = np.array(balanced_labels_reduced)==ct
    plt.scatter(embedding[mask,0],embedding[mask,1],label=ct,s=1)
plt.show()

# %%
import matplotlib.pyplot as plt
s=0.1
plt.figure(figsize=[10,10])
plt.scatter(np.log10(Gmu_max+1),np.log10(Gsep+1),s=s,alpha=1,c='c')
plt.scatter(np.log10(Gmu_max[mu_mask]+1),np.log10(Gsep[mu_mask]+1),s=s,alpha=1,c='k')
plt.scatter(np.log10(Gmu_max[sep_mask&mu_mask]+1),np.log10(Gsep[sep_mask&mu_mask]+1),s=s,alpha=1,c='b')
plt.scatter(np.log10(Gmu_max[std_mask&sep_mask&mu_mask]+1),np.log10(Gsep[std_mask&sep_mask&mu_mask]+1),s=s,alpha=1,c='g')
plt.scatter(np.log10(Gmu_max[dectree_mask&std_mask&sep_mask&mu_mask]+1),np.log10(Gsep[dectree_mask&std_mask&sep_mask&mu_mask]+1),s=1,alpha=1,c='r')
plt.xlabel('Gmu_max')
plt.ylabel('Gsep_max')
plt.show()

# %%
"""
Find 25 genes that seperate SST well
Find 25 genes that seperate CA1 well
find 25 genes that seperate CA
"""

# %%
low_level_celltypes = [ct for ct,nc in Counter(metadata['cell_type_alias_label']).items() if ('Sst' in ct)&(nc>10)]
low_level_labels = np.array(metadata['cell_type_alias_label'])

# %%
Gmu = np.zeros((len(genes),len(high_level_celltypes)))
for i,ct in tqdm(enumerate(high_level_celltypes),total=len(high_level_celltypes)):
    ct_indexes = list(metadata[metadata['cell_type_alias_label']==ct]['counts_loc'])
    if len(ct_indexes)>1:
        Gmu[:,i] = np.mean(normcounts[ct_indexes,:],axis=0)
    else:
        Gmu[:,i] = normcounts[ct_indexes,:]
Gmu_max = np.max(Gmu,axis=1)
Gsep = np.array([np.nanmean(np.abs(Gmu[i,:,None]-Gmu[i,None,:])) for i in tqdm(range(Gmu.shape[0]))])

# %%
plt.figure(figsize=[10,10])
plt.scatter(np.log10(Gmu_max+1),np.log10(Gsep+1),s=1,alpha=0.1)
d_min = np.log10(10+1)
d_max = np.log10(1000+1)
d_sep = np.log10(5+1)
m_min = np.log10(1+1)
m_max = np.log10(100+1)
m_sep = np.log10(0.5+1)
plt.plot([d_min,d_max],[d_sep,d_sep],c='r')
plt.plot([d_min,d_min],[d_sep,4],c='r')
plt.plot([d_max,d_max],[d_sep,4],c='r')
plt.plot([m_min,m_max],[m_sep,m_sep],c='g')
plt.plot([m_min,m_min],[m_sep,4],c='g')
plt.plot([m_max,m_max],[m_sep,4],c='g')
plt.xlabel('Gmu_max')
plt.ylabel('Gsep')
plt.show()

# %%
merfish_filtered_genes = np.array(genes)[(Gmu_max>1)&(Gmu_max<100)&(Gsep>0.5)]
pd.Series(merfish_filtered_genes).to_csv(os.path.join(base_path,'merfish_filtered_genes.csv'),index=False)
print(len(merfish_filtered_genes))
# Out:
# 8124
# /home/zach/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
"""
Deal with leafs with less than 10 cells
"""

# %%
import json
with open(os.path.join(base_path,'dend.json')) as f:
    dend = json.load(f)
def find_next_nodes(node):
    if 'leaf_attributes' in node.keys():
        A = None
        B = None
        C = node['leaf_attributes'][0]['original_label']
        H = node['leaf_attributes'][0]['height']
        Children = []
    elif 'node_attributes' in node.keys():
        try:
            A = node['children'][0]['node_attributes'][0]['original_label']
        except:
            A = node['children'][0]['leaf_attributes'][0]['original_label']
        try:
            B = node['children'][1]['node_attributes'][0]['original_label']
        except:
            B = node['children'][1]['leaf_attributes'][0]['original_label']
        C = node['node_attributes'][0]['original_label']
        H = node['node_attributes'][0]['height']
        Children = node['children']
    return A,B,C,H,Children
A_list = []
B_list = []
C_list = []
H_list = []
Children_list = []
A,B,C,H,Children = find_next_nodes(dend)
A_list.append(A)
B_list.append(B)
C_list.append(C)
H_list.append(H)
Children_list.extend(Children)
while len(Children_list)>0:
    new_Children_list = []
    for child in Children_list:
        A,B,C,H,Children = find_next_nodes(child)
        A_list.append(A)
        B_list.append(B)
        C_list.append(C)
        H_list.append(H)
        new_Children_list.extend(Children)
    Children_list = new_Children_list
linkage = pd.DataFrame()
linkage['A'] = A_list
linkage['B'] = B_list
linkage['C'] = C_list
linkage['H'] = H_list
linkage = linkage.sort_values('H')
linkage['Members'] = np.nan
for idx,row in tqdm(linkage.iterrows(),total=len(linkage)):
    cell_type = row['C']
    idx = linkage[linkage['C']==cell_type].index
    if cell_type in celltypes:
        members = len(metadata[metadata['cell_type_alias_label']==cell_type]['counts_loc'])
    else:
        try:
            members_A = linkage[(linkage['C']==row['A'])]['Members'].iloc[0]
            members_B = linkage[linkage['C']==row['B']]['Members'].iloc[0]
            members = members_A+members_B
        except:
            members = 0
    linkage['Members'].loc[idx] = members

# %%
import json
with open(os.path.join(base_path,'dend.json')) as f:
    dend = json.load(f)

# %%
def find_next_nodes(node):
    if 'leaf_attributes' in node.keys():
        A = None
        B = None
        C = node['leaf_attributes'][0]['original_label']
        H = node['leaf_attributes'][0]['height']
        Children = []
    elif 'node_attributes' in node.keys():
        try:
            A = node['children'][0]['node_attributes'][0]['original_label']
        except:
            A = node['children'][0]['leaf_attributes'][0]['original_label']
        try:
            B = node['children'][1]['node_attributes'][0]['original_label']
        except:
            B = node['children'][1]['leaf_attributes'][0]['original_label']
        C = node['node_attributes'][0]['original_label']
        H = node['node_attributes'][0]['height']
        Children = node['children']
    return A,B,C,H,Children

# %%
A_list = []
B_list = []
C_list = []
H_list = []
Children_list = []
A,B,C,H,Children = find_next_nodes(dend)
A_list.append(A)
B_list.append(B)
C_list.append(C)
H_list.append(H)
Children_list.extend(Children)
while len(Children_list)>0:
    new_Children_list = []
    for child in Children_list:
        A,B,C,H,Children = find_next_nodes(child)
        A_list.append(A)
        B_list.append(B)
        C_list.append(C)
        H_list.append(H)
        new_Children_list.extend(Children)
    Children_list = new_Children_list
linkage = pd.DataFrame()
linkage['A'] = A_list
linkage['B'] = B_list
linkage['C'] = C_list
linkage['H'] = H_list
linkage = linkage.sort_values('H')

# %%
linkage['Members'] = np.nan
for idx,row in tqdm(linkage.iterrows(),total=len(linkage)):
    cell_type = row['C']
    idx = linkage[linkage['C']==cell_type].index
    if cell_type in celltypes:
        members = len(metadata[metadata['cell_type_alias_label']==cell_type]['counts_loc'])
    else:
        try:
            members_A = linkage[(linkage['C']==row['A'])]['Members'].iloc[0]
            members_B = linkage[linkage['C']==row['B']]['Members'].iloc[0]
            members = members_A+members_B
        except:
            members = 0
    linkage['Members'].loc[idx] = members
# Out:
# 100%|██████████| 757/757 [03:03<00:00,  4.13it/s]

# %%
bad_leafs = list(linkage[linkage['Members']<10]['C'])
bad_cells = list(metadata[metadata['cell_type_alias_label'].isin(bad_leafs)].index)
metadata=metadata.drop(index = bad_cells)
metadata.to_csv(os.path.join(base_path,'sorted_metadata.csv'))
good_indexes = [i for i,cell in enumerate(cells) if not cell in bad_cells]
pd.Series(cells[good_indexes]).to_csv(os.path.join(base_path,'sorted_cells.csv'),index=False)

# %%
normcounts = normcounts[good_indexes,:]
np.save(os.path.join(base_path,'normcounts.npy'),normcounts)

# %%
del dredfish_normcounts

# %%
# Save to npy for work in python 
gene_df = pd.DataFrame(genes)
dredfish_normcounts = normcounts[:,list(gene_df[gene_df[0].isin(filtered_genes)].index)]
np.save(os.path.join(base_path,'dredfish_normcounts.npy'),dredfish_normcounts)
np.savetxt("dredfish_normcounts.csv", dredfish_normcounts, delimiter=",")
del dredfish_normcounts
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-c53f6e99776d> in <module>
#       3 dredfish_normcounts = normcounts[:,list(gene_df[gene_df[0].isin(filtered_genes)].index)]
#       4 np.save(os.path.join(base_path,'dredfish_normcounts.npy'),dredfish_normcounts)
# ----> 5 np.savetxt("dredfish_normcounts.csv", dredfish_normcounts, delimiter=",")
#       6 del dredfish_normcounts
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# ~/miniconda3/envs/pyspots-gpu/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1422             for row in X:
#    1423                 try:
# -> 1424                     v = format % tuple(row) + newline
#    1425                 except TypeError:
#    1426                     raise TypeError("Mismatch between array dtype ('%s') and "
# ...

# %%
# Save to npy for work in python 
gene_df = pd.DataFrame(genes)
merfish_normcounts = normcounts[:,list(gene_df[gene_df[0].isin(merfish_filtered_genes)].index)]
np.save(os.path.join(base_path,'merfish_normcounts.npy'),merfish_normcounts)
# np.savetxt("merfish_normcounts.csv", merfish_normcounts, delimiter=",")
del merfish_normcounts

# %%
import csv
from scipy import sparse
from tqdm import tqdm
import os
import numpy as np
base_path = '/bigstore/binfo/mouse/Brain/Sequencing/Allen_10X_SmartSeqTypes/'
dredfish_normcounts = np.load(os.path.join(base_path,'dredfish_normcounts.npy'))
