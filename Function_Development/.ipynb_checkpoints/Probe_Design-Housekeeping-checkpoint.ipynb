# %%
import pandas as pd
import numpy as np
from os import path
import gtfparse
import pyensembl
pyensembl.EnsemblRelease(release=87)
import gspread
from  oauth2client.service_account  import ServiceAccountCredentials
import gspread
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO

# %% [markdown]
# https://www.twilio.com/blog/2017/02/an-easy-way-to-read-and-write-to-a-google-spreadsheet-in-python.html
# Go to the Google APIs Console.
# Create a new project.
# Click Enable API. Search for and enable the Google Drive API.
# Create credentials for a Web Server to access Application Data.
# Name the service account and grant it a Project Role of Editor.
# Download the JSON file.
# Copy the JSON file to your code directory
# Open JSON and find "client_email"
# share google sheet with this email

# %%
scope = ['https://spreadsheets.google.com/feeds',
        'https://www.googleapis.com/auth/drive']
# Path to .json
path = '/bigstore/GeneralStorage/Zach/MERFISH/Probe_Design/ProbeDesign-92ebdb6a17a7.json'
creds = ServiceAccountCredentials.from_json_keyfile_name(path, scope)
client = gspread.authorize(creds)
# Start with a gene list 
expression_worksheet = client.open("Caitlin_Gene_List").sheet1
expression = expression_worksheet.get_all_records()
expression_df = pd.DataFrame(expression)
# Out:
# INFO:oauth2client.client:Refreshing access_token

# %%
expression_df
# Out:
#      Barcode                                        Description FPKM  \
# 0             4-aminobutyrate aminotransferase [Source:HGNC ...
# 1             abhydrolase domain containing 12 [Source:HGNC ...
# 2             abhydrolase domain containing 5 [Source:HGNC S...
# 3             acyl-CoA oxidase 1 [Source:HGNC Symbol;Acc:HGN...
# 4             acyl-CoA synthetase long chain family member 4...
# 5             actinin alpha 1 [Source:HGNC Symbol;Acc:HGNC:163]
# 6             activin A receptor type 1 [Source:HGNC Symbol;...
# 7             ADAM metallopeptidase domain 10 [Source:NCBI g...
# 8             ADAM metallopeptidase domain 17 [Source:HGNC S...
# 9             ADAM metallopeptidase domain 9 [Source:NCBI ge...
# 10            ADP dependent glucokinase [Source:HGNC Symbol;...
# 11            adenylosuccinate lyase [Source:NCBI gene;Acc:1...
# 12            AF4/FMR2 family member 1 [Source:HGNC Symbol;A...
# 13            AF4/FMR2 family member 4 [Source:HGNC Symbol;A...
# 14               aftiphilin [Source:HGNC Symbol;Acc:HGNC:25951]
# 15            ArfGAP with FG repeats 1 [Source:NCBI gene;Acc...
# 16                      agrin [Source:HGNC Symbol;Acc:HGNC:329]
# 17            adenosylhomocysteinase like 1 [Source:HGNC Sym...
# 18            Abelson helper integration site 1 [Source:HGNC...
# 19            AKT serine/threonine kinase 3 [Source:NCBI gen...
# 20            activated leukocyte cell adhesion molecule [So...
# 21            aldehyde dehydrogenase 5 family member A1 [Sou...
# 22            ALS2, alsin Rho guanine nucleotide exchange fa...
# 23            adenosylmethionine decarboxylase 1 [Source:NCB...
# 24            APC membrane recruitment protein 2 [Source:HGN...
# 25            angel homolog 1 [Source:HGNC Symbol;Acc:HGNC:1...
# 26                  ankyrin 2 [Source:HGNC Symbol;Acc:HGNC:493]
# 27            ankyrin repeat and IBR domain containing 1 [So...
# 28            ankyrin repeat domain 13C [Source:HGNC Symbol;...
# 29            ankyrin repeat domain 40 [Source:HGNC Symbol;A...
# ...      ...                                                ...  ...
# 1340          Taeniopygia guttata ubiquitin conjugating enzy...
# 1341
# 1342          Taeniopygia guttata ubiquitin conjugating enzy...
# 1343
# 1344          ubiquitin-like domain containing CTD phosphata...
# 1345
# 1346
# 1347
# 1348
# 1349            visinin like 1 [Source:NCBI gene;Acc:100190342]
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# 1359          Taeniopygia guttata Yip1 domain family member ...
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# 1366          Taeniopygia guttata zinc finger FYVE-type cont...
# 1367
# 1368
# 1369
#
#           Gene             Gene_ID Isoform % Length Oligos  \
# 0         ABAT  ENSTGUG00000004611             1506
# 1       ABHD12  ENSTGUG00000004985             1648
# 2        ABHD5  ENSTGUG00000003814             1011
# 3        ACOX1  ENSTGUG00000008167             2595
# 4        ACSL4  ENSTGUG00000004291             2139
# 5        ACTN1  ENSTGUG00000011477             2571
# 6        ACVR1  ENSTGUG00000012182             1524
# 7       ADAM10  ENSTGUG00000006081             2714
# 8       ADAM17  ENSTGUG00000013028             2388
# 9        ADAM9  ENSTGUG00000004989             2478
# 10       ADPGK  ENSTGUG00000004179             1266
# 11        ADSL  ENSTGUG00000010111             1464
# 12        AFF1  ENSTGUG00000002726             3558
# 13        AFF4  ENSTGUG00000000187             3465
# 14       AFTPH  ENSTGUG00000002302             1677
# 15       AGFG1  ENSTGUG00000008234             2224
# 16        AGRN  ENSTGUG00000004020             4236
# 17      AHCYL1  ENSTGUG00000000826             2067
# 18        AHI1  ENSTGUG00000011488             3051
# 19        AKT3  ENSTGUG00000008212             1440
# 20       ALCAM  ENSTGUG00000013613             2204
# 21     ALDH5A1  ENSTGUG00000006463             1476
# 22        ALS2  ENSTGUG00000010168             5585
# 23        AMD1  ENSTGUG00000012045             1026
# 24       AMER2  ENSTGUG00000011464             1242
# 25      ANGEL1  ENSTGUG00000012264             1989
# 26        ANK2  ENSTGUG00000001807            11166
# 27      ANKIB1  ENSTGUG00000001471             3285
# 28    ANKRD13C  ENSTGUG00000010275             1293
# 29     ANKRD40  ENSTGUG00000009204             1714
# ...        ...                 ...       ...    ...    ...
# 1340     UBE2N                                 1102
# 1341    UBE2Q2
# 1342    UBE2V2                                 1201
# 1343     UBE2W
# 1344    UBLCP1                                 1703
# 1345     UHRF2
# 1346    UNC13A
# 1347      UTRN
# 1348       VCL
# 1349     VSNL1                                 1564
# 1350     WDFY1
# 1351     WDR44
# 1352     WDR47
# 1353     WHSC1
# 1354      WSB1
# 1355      WWP1
# 1356      XIAP
# 1357       XPC
# 1358   XPNPEP3
# 1359     YIPF3                                 1408
# 1360    YTHDC2
# 1361    ZBTB44
# 1362    ZC3H13
# 1363    ZCCHC6
# 1364    ZFP462
# 1365   ZFYVE16
# 1366   ZFYVE21                                 1409
# 1367    ZNF638
# 1368      ZZZ3
# 1369       GFP
#
#                      Rationale       Transcript_ID       ZF Gene
# 0     striatal/pallidal_marker  ENSTGUT00000004827
# 1              neuron_marker_b  ENSTGUT00000005200
# 2                miR-128target  ENSTGUT00000003977
# 3             astrocyte_marker  ENSTGUT00000008556
# 4             microglia_marker  ENSTGUT00000004521
# 5     striatal/pallidal_marker  ENSTGUT00000011968
# 6           endothelium_marker  ENSTGUT00000012693
# 7                miR-128target  ENSTGUT00000006342
# 8             microglia_marker  ENSTGUT00000013573
# 9             microglia_marker  ENSTGUT00000005272
# 10            microglia_marker  ENSTGUT00000004352
# 11             neuron_marker_b  ENSTGUT00000010552
# 12          endothelium_marker  ENSTGUT00000002847
# 13               miR-128target  ENSTGUT00000000195
# 14            microglia_marker  ENSTGUT00000002399
# 15               miR-128target  ENSTGUT00000008594
# 16               miR-128target  ENSTGUT00000004205
# 17            astrocyte_marker  ENSTGUT00000000873
# 18             neuron_marker_b  ENSTGUT00000011972
# 19          endothelium_marker  ENSTGUT00000008580
# 20    striatal/pallidal_marker  ENSTGUT00000014176
# 21    striatal/pallidal_marker  ENSTGUT00000006725
# 22             neuron_marker_b  ENSTGUT00000010664
# 23              oligo_marker_b  ENSTGUT00000012549
# 24               miR-128target  ENSTGUT00000011942
# 25              oligo_marker_b  ENSTGUT00000012771
# 26               miR-128target  ENSTGUT00000001892
# 27              oligo_marker_b  ENSTGUT00000001531
# 28             neuron_marker_b  ENSTGUT00000010715
# 29              oligo_marker_b  ENSTGUT00000009592
# ...                        ...                 ...           ...
# 1340           neuron_marker_b  ENSTGUT00000008600         UBE2N
# 1341  striatal/pallidal_marker                            UBE2Q2
# 1342           neuron_marker_b  ENSTGUT00000011367        UBE2V2
# 1343             miR-128target                             UBE2W
# 1344           neuron_marker_b  ENSTGUT00000000601        UBLCP1
# 1345           neuron_marker_b                             UHRF2
# 1346           neuronal_marker                      LOC105760238
# 1347  striatal/pallidal_marker                              UTRN
# 1348             miR-128target                               VCL
# 1349  striatal/pallidal_marker  ENSTGUT00000013652         VSNL1
# 1350        endothelium_marker                             WDFY1
# 1351            oligo_marker_b                             WDR44
# 1352           neuron_marker_b                             WDR47
# 1353           neuron_marker_b                             WHSC1
# 1354  striatal/pallidal_marker
# 1355           neuron_marker_b                              WWP1
# 1356           neuron_marker_b                              XIAP
# 1357            oligo_marker_b                               XPC
# 1358          astrocyte_marker                      LOC100229665
# 1359        endothelium_marker  ENSTGUT00000009532         YIPF3
# 1360          microglia_marker                            YTHDC2
# 1361            oligo_marker_b                            ZBTB44
# 1362            oligo_marker_b                            ZC3H13
# 1363          microglia_marker                            ZCCHC6
# 1364  striatal/pallidal_marker
# 1365            oligo_marker_b                           ZFYVE16
# 1366          astrocyte_marker  ENSTGUT00000013412       ZFYVE21
# 1367             miR-128target                            ZNF638
# 1368             miR-128target                              ZZZ3
# 1369                  reporter
#
# [1370 rows x 11 columns]

# %%
# removing trnascript versions from worksheet
# Select a range
Transcript_ID = expression_worksheet.range('G2:G189')
# Edit range
for cell in Transcript_ID:
    cell.value = cell.value.split('.')[0]
# Update in batch
expression_worksheet.update_cells(Transcript_ID)
# Out:
# {'spreadsheetId': '11MMvEY4s8oUIGf5kyoA4QOKs-Br2myyNooNmSO7-nEU',
#  'updatedCells': 188,
#  'updatedColumns': 1,
#  'updatedRange': 'Sheet1!G2:G189',
#  'updatedRows': 188}

# %%
def col_cells(worksheet, col):
    """Returns a range of cells in a `worksheet`'s column `col`."""
    start_cell = worksheet.get_addr_int(1, col)
    end_cell = worksheet.get_addr_int(worksheet.row_count, col)

    return worksheet.range('%s:%s' % (start_cell, end_cell))

# %%
def read_codebook(cbook_fname):
    """Read CSV of n-bit codewords."""
    cwords = []
    with open(cbook_fname, 'r') as f:
        column_name = f.readline().strip()
        for l in f.readlines():
            cwords.append(l.strip())
    return cwords
codewords = read_codebook('/home/zach/Documents/Untitled Folder/cbook_140MHD4_200MHD2.txt') # need to fill in
np.random.shuffle(codewords)
print('Number of codewords in codebook -', len(codewords))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-438f90632833> in <module>()
#       7             cwords.append(l.strip())
#       8     return cwords
# ----> 9 codewords = read_codebook('/home/zach/Documents/Untitled Folder/cbook_140MHD4_200MHD2.txt') # need to fill in
#      10 np.random.shuffle(codewords)
#      11 print('Number of codewords in codebook -', len(codewords))
#
# <ipython-input-10-438f90632833> in read_codebook(cbook_fname)
#       2     """Read CSV of n-bit codewords."""
#       3     cwords = []
# ----> 4     with open(cbook_fname, 'r') as f:
#       5         column_name = f.readline().strip()
#       6         for l in f.readlines():
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/zach/Documents/Untitled Folder/cbook_140MHD4_200MHD2.txt'

# %%
transcripts.columns
# Out:
# Index(['Gene stable ID', 'Transcript stable ID', 'Gene description',
#        'Transcript length (including UTRs and CDS)', 'Transcript type',
#        'Gene type', 'Gene name', 'NCBI gene ID'],
#       dtype='object')

# %% [markdown]
# Need to download biomart file for the species of interest
# This can be done here http://uswest.ensembl.org/biomart/martview/121d069e69616b12e28fa129a1e20f1c

# %%
def geneSymbol_to_ensembl(gene_symbol_list, biomart_download_fname,
                          organism='mouse', min_length=1000):
    """
    Look up the ensembl of gene symbols.
    """
    annotations = []
    with open(biomart_download_fname, 'r') as f:
        transcript_df = pd.read_csv(f)
        #genes = [i.value for i in gene_symbol_list if i != '']
        genes = gene_symbol_list
        transcript_df = transcript_df[transcript_df[u'Gene name'].isin(genes)]
    for cell in gene_symbol_list:
        gene = cell#.value
        if gene == '':
            continue

        transcripts = transcript_df[transcript_df[u'Gene name'] == gene].drop_duplicates('Transcript stable ID')
        transcripts = transcripts[transcripts[u'Transcript type']==u'protein_coding'].sort_values('Transcript length (including UTRs and CDS)', ascending=False)
        
        if len(transcripts)==0:
            print('Failed finding: ', gene)
            annotations.append((gene, None))
        elif transcripts.iloc[0]['Transcript length (including UTRs and CDS)'] > min_length:
            annotations.append((gene, transcripts))
        else:
            print('Gene too short: ', gene)
            annotations.append((gene, transcripts))
    return annotations
#

# %%
def ensymbl_to_geneinfo(Gene_Stable_IDs, biomart_download_fname_path,
                          organism='mouse', min_length=1000):
    annotations = []
    with open(biomart_download_fname_path, 'r') as f:
        transcript_df = pd.read_csv(f)
        genes = [i.value for i in Gene_Stable_IDs if i != '']
        transcript_df = transcript_df[transcript_df[u'Gene stable ID'].isin(genes)]
    for cell in Gene_Stable_IDs:
        gene = cell.value
        if gene == '':
            continue
        transcripts = transcript_df[transcript_df[u'Gene stable ID'] == gene].drop_duplicates('Transcript stable ID')
        transcripts = transcripts[transcripts[u'Transcript type']==u'protein_coding'].sort_values('Transcript length (including UTRs and CDS)', ascending=False)
        if len(transcripts)==0:
            print('Failed finding: ', gene)
            annotations.append((gene, None))
        elif transcripts.iloc[0]['Transcript length (including UTRs and CDS)'] > min_length:
            annotations.append((gene, transcripts))
        else:
            print('Gene too short: ', gene)
            annotations.append((gene, transcripts))
    return annotations

# %%
def Trascriptome_append(transcript_IDs,file):
    annotations = []
    with open(file, 'r') as f:
        transcriptome_df = pd.read_csv(f)
        genes = [i.value for i in transcript_IDs if i != '']
        transcriptome_df = transcriptome_df[transcriptome_df[u'transcript_id'].isin(genes)] 
    for cell in transcript_IDs:
        gene = cell.value
        if gene == '':
            continue
        transcripts = transcript_df[transcript_df[u'transcript_id'] == gene]
        if len(transcripts)==0:
            print('Failed finding: ', gene)
            annotations.append((gene, None))
        else:
            annotations.append((gene, transcripts))
    return annotations

# %%
f = '/bigstore/GeneralStorage/Zach/MERFISH/Probe_Design/results/Caitlin/Hilliard2012refined.xlsx'
Hilliard = pd.read_excel(f)
f = '/bigstore/GeneralStorage/Zach/MERFISH/Probe_Design/results/Caitlin/Burkett2018TableS1.xlsx'
Burkette = pd.read_excel(f)

# %%
import matplotlib.pyplot as plt
plt.hist(np.log2(Hilliard['medExpr.X']),bins=100)
plt.show()

# %%
biomart_download_fname = '/bigstore/binfo/zebra_finch/zebra_finch_biomart.txt'
gene_symbol_list = expression_df['Gene']
annotations = geneSymbol_to_ensembl(gene_symbol_list, biomart_download_fname, organism='finch', min_length=1000)
# Out:
# Gene too short:  AP3S1
# Gene too short:  ARF1
# Gene too short:  ARHGDIB
# Gene too short:  ARL8B
# Gene too short:  ARMC1
# Gene too short:  ASB8
# Gene too short:  ASRGL1
# Gene too short:  ATP1B3
# Gene too short:  B4GALT1
# Gene too short:  BAG1
# Gene too short:  BASP1
# Gene too short:  BCL7B
# Gene too short:  BET1L
# Gene too short:  BHLHE41
# Failed finding:  C16ORF70
# Failed finding:  C1ORF21
# Gene too short:  C1QTNF4
# Gene too short:  CA7
# Gene too short:  CABP1
# Gene too short:  CALB1
# Gene too short:  CAMK2B
# Gene too short:  CBFB
# Gene too short:  CCDC92
# Gene too short:  CCND3
# Gene too short:  CCNDBP1
# Gene too short:  CCNH
# Gene too short:  CD99L2
# Gene too short:  CDKN2C
# Gene too short:  CDO1
# Gene too short:  CHPT1
# Gene too short:  CHST11
# Gene too short:  CITED2
# Gene too short:  CNIH4
# Gene too short:  CNN3
# Gene too short:  CNOT7
# Gene too short:  CNRIP1
# Gene too short:  COMMD6
# Gene too short:  COPS7B
# Gene too short:  COPS8
# Gene too short:  CRH
# Gene too short:  CYB561
# Gene too short:  CYB5B
# Gene too short:  DBNDD2
# Gene too short:  DCUN1D1
# Gene too short:  DHDDS
# Gene too short:  DLK2
# Gene too short:  DLX1
# Gene too short:  DLX2
# Gene too short:  DNAJB9
# Gene too short:  DUSP12
# Gene too short:  DYNLL2
# Gene too short:  ECHS1
# Gene too short:  EEF1B2
# Gene too short:  ELOVL1
# Gene too short:  ELOVL5
# Gene too short:  ERH
# Gene too short:  ERLIN2
# Gene too short:  FAM107A
# Gene too short:  FDX1
# Gene too short:  FEZ1
# Gene too short:  FNDC4
# Gene too short:  FNDC5
# Gene too short:  FOSL2
# Gene too short:  FOXN2
# Gene too short:  GMFB
# Gene too short:  GOLGA7
# Gene too short:  GSG1L
# Gene too short:  GSTK1
# Gene too short:  GTF3C6
# Gene too short:  HADH
# Gene too short:  HINT3
# Gene too short:  HMGB3
# Gene too short:  HNRNPA0
# Gene too short:  HPCA
# Gene too short:  HTATIP2
# Gene too short:  ID4
# Gene too short:  ING2
# Gene too short:  ING5
# Gene too short:  KCNJ3
# Gene too short:  KCTD1
# Gene too short:  KCTD12
# Gene too short:  KDSR
# Gene too short:  LAMTOR2
# Gene too short:  LASP1
# Gene too short:  LDHA
# Gene too short:  LGALS8
# Gene too short:  LIN52
# Gene too short:  LIX1L
# Gene too short:  LRRC58
# Gene too short:  LSM12
# Gene too short:  LZTFL1
# Gene too short:  LZTS1
# Gene too short:  MAFF
# Gene too short:  MANBAL
# Gene too short:  MBLAC2
# Gene too short:  MDFIC
# Gene too short:  MDM4
# Gene too short:  MED28
# Gene too short:  MLEC
# Gene too short:  MLF1
# Gene too short:  MTCH1
# Gene too short:  MXRA7
# Gene too short:  NAIF1
# Gene too short:  NDEL1
# Gene too short:  NDUFA6
# Gene too short:  NDUFB10
# Gene too short:  NDUFB9
# Gene too short:  NDUFS6
# Gene too short:  NECAP1
# Gene too short:  NEK7
# Gene too short:  NFE2L1
# Gene too short:  NPTN
# Gene too short:  NR2F6
# Gene too short:  NUS1
# Gene too short:  NXT2
# Gene too short:  OPRM1
# Gene too short:  OSTF1
# Gene too short:  OSTM1
# Gene too short:  OTUD1
# Gene too short:  PACRGL
# Gene too short:  PAFAH1B2
# Gene too short:  PALM2
# Gene too short:  PARP11
# Gene too short:  PCGF3
# Gene too short:  PDCL3
# Gene too short:  PDXK
# Gene too short:  PEX11B
# Gene too short:  PGP
# Gene too short:  PGRMC1
# Gene too short:  PHC2
# Gene too short:  PLCXD3
# Gene too short:  PLEKHA3
# Gene too short:  PLEKHB1
# Gene too short:  PMEPA1
# Gene too short:  PPP1R7
# Gene too short:  PTS
# Gene too short:  PTTG1IP
# Gene too short:  QDPR
# Gene too short:  RAB27A
# Gene too short:  RAB31
# Gene too short:  RAB39B
# Gene too short:  RAB3B
# Gene too short:  RAB4A
# Gene too short:  RAB8B
# Gene too short:  RALYL
# Gene too short:  RAP1B
# Gene too short:  RASD2
# Gene too short:  RBM18
# Gene too short:  RCAN2
# Gene too short:  REEP3
# Gene too short:  RELL1
# Gene too short:  RFK
# Gene too short:  RGS17
# Gene too short:  RHOG
# Gene too short:  RILPL2
# Gene too short:  RIT1
# Gene too short:  RNF115
# Gene too short:  RNF141
# Gene too short:  RNF217
# Gene too short:  RPL10A
# Gene too short:  RPL11
# Gene too short:  RPL19
# Gene too short:  RPL35A
# Gene too short:  RPLP2
# Gene too short:  RPS2
# Gene too short:  RPS21
# Gene too short:  RPS25
# Gene too short:  RPS26
# Gene too short:  SAMD12
# Gene too short:  SCOC
# Gene too short:  SCRG1
# Gene too short:  SERTAD4
# Gene too short:  SF3B4
# Gene too short:  SF3B5
# Gene too short:  SFXN3
# Gene too short:  SNAPC3
# Gene too short:  SOSTDC1
# Gene too short:  SPAG7
# Gene too short:  SPRY2
# Gene too short:  ST8SIA3
# Gene too short:  SUMF2
# Gene too short:  SYNDIG1L
# Gene too short:  TEF
# Gene too short:  TFEB
# Gene too short:  TMED5
# Gene too short:  TMEM123
# Gene too short:  TMEM170B
# Gene too short:  TMEM65
# Gene too short:  TMX4
# Gene too short:  TTC19
# Gene too short:  TTC9
# Gene too short:  UBE2K
# Gene too short:  UCHL1
# Gene too short:  USE1
# Gene too short:  VAMP1
# Gene too short:  VBP1
# Gene too short:  VMA21
# Gene too short:  VSTM2A
# Gene too short:  WIPF2
# Gene too short:  YAF2
# Gene too short:  YPEL2
# Gene too short:  YPEL5
# Gene too short:  ZDHHC2
# Failed finding:  ABLIM2
# Failed finding:  ACAA2
# Failed finding:  ACVR2A
# Failed finding:  ADD3
# Failed finding:  ADSSL1
# Failed finding:  AGTPBP1
# Failed finding:  ALDH3A2
# Failed finding:  ALDH9A1
# Failed finding:  ANAPC4
# Failed finding:  ANKMY2
# Failed finding:  ANKRD11
# Failed finding:  ARHGAP32
# Failed finding:  ARID2
# Failed finding:  ARL5B
# Failed finding:  ASPA
# Failed finding:  ATP11B
# Failed finding:  ATP5G2
# Failed finding:  ATXN1L
# Failed finding:  ATXN7
# Failed finding:  B3GALTL
# Failed finding:  BAIAP2
# Failed finding:  BBS7
# Failed finding:  BBX
# Failed finding:  BECN1
# Failed finding:  BID
# Failed finding:  BLOC1S5
# Failed finding:  BMI1
# Failed finding:  BRE
# Failed finding:  BTRC
# Failed finding:  C16ORF52
# Gene too short:  CACYBP
# Failed finding:  CAND1
# Failed finding:  CASP2
# Failed finding:  CASP8AP2
# Failed finding:  CBL
# Failed finding:  CBLL1
# Failed finding:  CBLN1
# Failed finding:  CCDC88C
# Gene too short:  CCK
# Failed finding:  CDC14B
# Gene too short:  CDC26
# Failed finding:  CDK12
# Failed finding:  CDK5RAP2
# Failed finding:  CHM
# Failed finding:  CHMP2A
# Failed finding:  CHSY1
# Failed finding:  CLASP1
# Failed finding:  CLDN11
# Failed finding:  CNKSR2
# Failed finding:  CNOT6L
# Failed finding:  CNOT8
# Failed finding:  CNTN1
# Failed finding:  COMT
# Gene too short:  COX6A1
# Failed finding:  CPD
# Failed finding:  CPOX
# Failed finding:  CTDSPL
# Failed finding:  CTDSPL2
# Failed finding:  CTSC
# Failed finding:  CXADR
# Gene too short:  DCTN3
# Failed finding:  DDX24
# Failed finding:  DEF8
# Failed finding:  DENND5A
# Failed finding:  DHX30
# Failed finding:  DMXL2
# Failed finding:  DNAJC2
# Failed finding:  DNAJC3
# Failed finding:  DNTTIP2
# Failed finding:  DOCK10
# Failed finding:  DPY19L3
# Failed finding:  DTNA
# Failed finding:  DTNB
# Failed finding:  EEF1G
# Failed finding:  EGR2
# Failed finding:  EGR3
# Failed finding:  EIF6
# Failed finding:  EML5
# Failed finding:  ESYT2
# Failed finding:  EVL
# Failed finding:  FAM105A
# Failed finding:  FAM122B
# Failed finding:  FAM134C
# Failed finding:  FAM177A1
# Failed finding:  FAM199X
# Failed finding:  FAM3C
# Failed finding:  FAR1
# Failed finding:  FBXO21
# Failed finding:  FBXO33
# Failed finding:  FGD4
# Failed finding:  FHL2
# Failed finding:  FOXP1
# Failed finding:  GABRB2
# Failed finding:  GABRG2
# Failed finding:  GADD45B
# Failed finding:  GBA
# Gene too short:  GJB1
# Failed finding:  GNB5
# Failed finding:  GOSR2
# Failed finding:  GPR88
# Gene too short:  GPX4
# Failed finding:  GRAMD3
# Gene too short:  GRB2
# Failed finding:  GRIK5
# Failed finding:  GRM4
# Gene too short:  H3F3A
# Failed finding:  HDAC8
# Failed finding:  HEBP1
# Failed finding:  HECTD1
# Failed finding:  HEXDC
# Failed finding:  HIBCH
# Failed finding:  HIGD2A
# Failed finding:  HIPK3
# Failed finding:  HMGN2
# Failed finding:  HS2ST1
# Failed finding:  HS6ST2
# Failed finding:  HSPD1
# Failed finding:  IFNAR2
# Failed finding:  IFNGR1
# Failed finding:  IKZF5
# Failed finding:  INPP5F
# Failed finding:  INTS6
# Failed finding:  INTS8
# Failed finding:  IRS4
# Failed finding:  ITGA6
# Failed finding:  ITGB1
# Failed finding:  ITPKA
# Failed finding:  ITPR1
# Failed finding:  JMJD1C
# Failed finding:  KCNAB1
# Failed finding:  KIAA1551
# Failed finding:  KLC1
# Failed finding:  KLHL2
# Failed finding:  KMT2C
# Failed finding:  LACTB
# Failed finding:  LANCL2
# Failed finding:  LGMN
# Failed finding:  LIMS2
# Failed finding:  LRBA
# Failed finding:  MAP2K6
# Failed finding:  MAPK14
# Failed finding:  MAPK8
# Failed finding:  MED17
# Failed finding:  MKL2
# Failed finding:  MLH3
# Failed finding:  MOB1B
# Failed finding:  MRPL48
# Failed finding:  MRPL50
# Failed finding:  MRPS18C
# Failed finding:  MSRA
# Failed finding:  MTDH
# Failed finding:  MTMR3
# Failed finding:  MYO5B
# Failed finding:  MYO9A
# Failed finding:  MYT1L
# Failed finding:  NAA16
# Failed finding:  NCOA7
# Gene too short:  NDFIP1
# Failed finding:  NDUFC1
# Failed finding:  NDUFV3
# Failed finding:  NEBL
# Failed finding:  NEFM
# Failed finding:  NFS1
# Failed finding:  NPEPPS
# Failed finding:  NRBF2
# Failed finding:  NSD1
# Failed finding:  NT5C2
# Gene too short:  NTS
# Failed finding:  NUP210
# Failed finding:  OLA1
# Failed finding:  OSBPL9
# Failed finding:  OTUD6B
# Failed finding:  OXCT1
# Failed finding:  P4HA1
# Failed finding:  PANK1
# Failed finding:  PANX1
# Failed finding:  PARM1
# Failed finding:  PARP1
# Failed finding:  PDCD4
# Failed finding:  PDE8A
# Failed finding:  PDS5A
# Failed finding:  PELI1
# Failed finding:  PER2
# Gene too short:  PFDN1
# Failed finding:  PHC1
# Failed finding:  PITPNC1
# Failed finding:  PKD2
# Failed finding:  PKIA
# Failed finding:  PKIB
# Gene too short:  PLLP
# Failed finding:  PNKD
# Failed finding:  POLDIP3
# Failed finding:  PPP1CA
# Failed finding:  PPP1R2
# Failed finding:  PPP3CB
# Failed finding:  PPP4R4
# Failed finding:  PRDM8
# Failed finding:  PRKCB
# Failed finding:  PRPF38B
# Failed finding:  PRPS1
# Failed finding:  PSEN1
# Gene too short:  PSMG3
# Failed finding:  PTEN
# Failed finding:  PTPN1
# Failed finding:  PTPN5
# Failed finding:  PTPRT
# Failed finding:  PTTG1
# Failed finding:  PUF60
# Gene too short:  PVALB
# Failed finding:  PXK
# Failed finding:  RAP2B
# Failed finding:  RAPGEF6
# Failed finding:  RARB
# Failed finding:  RASA2
# Failed finding:  RASAL2
# Failed finding:  RBBP5
# Gene too short:  RBM8A
# Failed finding:  RIC8B
# Failed finding:  RINT1
# Failed finding:  RNMT
# Failed finding:  ROCK1
# Gene too short:  RPL7
# Failed finding:  RPL7A
# Failed finding:  RPL8
# Gene too short:  RPLP1
# Gene too short:  RPS11
# Gene too short:  RPS15
# Failed finding:  RPS24
# Failed finding:  RPS27A
# Failed finding:  RPS3
# Failed finding:  RPS6KA5
# Gene too short:  RPSA
# Failed finding:  RYBP
# Failed finding:  RYR1
# Failed finding:  SAAL1
# Failed finding:  SAMM50
# Failed finding:  SCN3B
# Failed finding:  SEC61A2
# Failed finding:  SECISBP2L
# Failed finding:  SEMA3D
# Failed finding:  SEMA7A
# Failed finding:  SENP2
# Failed finding:  SERTAD2
# Failed finding:  SETD7
# Failed finding:  SIK1
# Failed finding:  SIPA1L1
# Failed finding:  SLC1A2
# Failed finding:  SLC25A32
# Failed finding:  SLC33A1
# Failed finding:  SLC6A11
# Failed finding:  SMARCA1
# Failed finding:  SMARCC1
# Failed finding:  SMC5
# Failed finding:  SMYD2
# Failed finding:  SNRNP35
# Failed finding:  SNX1
# Failed finding:  SNX25
# Gene too short:  SOD1
# Failed finding:  SPG21
# Failed finding:  SPRY3
# Failed finding:  SRGAP2
# Failed finding:  SRPK2
# Failed finding:  SSBP2
# Failed finding:  SST
# Failed finding:  SSTR4
# Failed finding:  ST3GAL5
# Failed finding:  STAG1
# Failed finding:  STK40
# Failed finding:  STX1A
# Failed finding:  SURF4
# Failed finding:  SYNJ2BP
# Failed finding:  TADA2A
# Failed finding:  TAF1
# Failed finding:  TBC1D7
# Failed finding:  TCTN3
# Failed finding:  TECR
# Failed finding:  TENM2
# Failed finding:  TGFBR1
# Failed finding:  THAP11
# Failed finding:  TIAM2
# Gene too short:  TIMM17A
# Gene too short:  TIMM9
# Failed finding:  TJP1
# Failed finding:  TMEM141
# Failed finding:  TMEM151B
# Failed finding:  TMEM214
# Gene too short:  TMEM41A
# Failed finding:  TMEM88
# Failed finding:  TMOD3
# Failed finding:  TMX1
# Failed finding:  TNRC18
# Failed finding:  TNRC6B
# Failed finding:  TOMM70A
# Failed finding:  TOP1
# Failed finding:  TPST1
# Failed finding:  TRAPPC8
# Failed finding:  TRHDE
# Failed finding:  TRIB1
# Failed finding:  TRIM37
# Failed finding:  TRIM59
# Gene too short:  TTR
# Failed finding:  TUBB2A
# Failed finding:  UBE2F
# Failed finding:  UBE2Q2
# Failed finding:  UBE2W
# Failed finding:  UHRF2
# Failed finding:  UNC13A
# Failed finding:  UTRN
# Failed finding:  VCL
# Failed finding:  WDFY1
# Failed finding:  WDR44
# Failed finding:  WDR47
# Failed finding:  WHSC1
# Failed finding:  WSB1
# Failed finding:  WWP1
# Failed finding:  XIAP
# Failed finding:  XPC
# Failed finding:  XPNPEP3
# Failed finding:  YTHDC2
# Failed finding:  ZBTB44
# Failed finding:  ZC3H13
# Failed finding:  ZCCHC6
# Failed finding:  ZFP462
# Failed finding:  ZFYVE16
# Failed finding:  ZNF638
# Failed finding:  ZZZ3
# Failed finding:  GFP

# %%
# Add FPKM data
transcript_IDs = expression_worksheet.range('G2:G189')
file = '/bigstore/GeneralStorage/Rob/merfish/MERFISH_analysis-master/mouse/Cornea/Expression/no_versions_isoforms_tracking.csv'
Transcriptome_annotations = Trascriptome_append(transcript_IDs,file)
FPKM = expression_worksheet.range('C2:C189')
for idx, g in enumerate(Transcriptome_annotations):
    info = g[1]
    if info is None:
        continue
    fpkm = info['FPKM'].iloc[0]
    FPKM[idx].value = fpkm
expression_worksheet.update_cells(FPKM)
# Out:
# Failed finding:  ENSMUST00000071134
# {'spreadsheetId': '11MMvEY4s8oUIGf5kyoA4QOKs-Br2myyNooNmSO7-nEU',
#  'updatedCells': 188,
#  'updatedColumns': 1,
#  'updatedRange': 'Sheet1!C2:C189',
#  'updatedRows': 188}

# %%
# build transcriptome file for matlab
# normally from RNAseq
transcriptome = pd.DataFrame(columns=['transcript_id','class_code','nearest_ref_id','gene_id','gene_short_name','tss_id','locus','length','coverage','FPKM','FPKM_conf_lo','FPKM_conf_hi','FPKM_status'
])
transcriptome.transcript_id = expression_df.Transcript_ID
transcriptome.gene_id = expression_df.Gene_ID
transcriptome.length = expression_df.Length
transcriptome.FPKM = expression_df.FPKM
transcriptome
transcriptome.to_csv('/bigstore/GeneralStorage/Zach/MERFISH/Probe_Design/results/Caitlin/transcriptome.csv',index=False)

# %%
# Add info to spreadsheet
# WARNING - you must figure out column numbers and change bits for new gene sets
biomart_download_fname = '/bigstore/binfo/zebra_finch/zebra_finch_biomart.txt'
gene_symbol_list = expression_df['Gene']
gene_annotations = geneSymbol_to_ensembl(gene_symbol_list, biomart_download_fname, organism='finch', min_length=1000)
gname = expression_worksheet.range('F2:F3000')
tname = expression_worksheet.range('G2:G3000')
length = expression_worksheet.range('D2:D3000')
descript = expression_worksheet.range('B2:B3000')
gene = expression_worksheet.range('A2:A3000')
loc = -1
update = []
for idx, g in enumerate(gene_annotations):
    info = g[1]
    if info is None:
        continue
    #Need to better select transcripts here
    max_transcript = info['Transcript stable ID'].iloc[loc]
    max_length = info['Transcript length (including UTRs and CDS)'].iloc[loc]
    descript_val = info['Gene description'].iloc[loc]
    gene_name = info['Gene name'].iloc[loc]
    gene_id = info['Gene stable ID'].iloc[loc]
    tname[idx].value = max_transcript
    length[idx].value = str(max_length)
    descript[idx].value = str(descript_val)
    gene[idx].value = str(gene_name)
    gname[idx].value = str(gene_id)
expression_worksheet.update_cells(tname)
expression_worksheet.update_cells(length)
expression_worksheet.update_cells(descript)
expression_worksheet.update_cells(gene)
expression_worksheet.update_cells(gname)
# Out:
# Gene too short:  AP3S1
# Gene too short:  ARF1
# Gene too short:  ARHGDIB
# Gene too short:  ARL8B
# Gene too short:  ARMC1
# Gene too short:  ASB8
# Gene too short:  ASRGL1
# Gene too short:  ATP1B3
# Gene too short:  B4GALT1
# Gene too short:  BAG1
# Gene too short:  BASP1
# Gene too short:  BCL7B
# Gene too short:  BET1L
# Gene too short:  BHLHE41
# Failed finding:  C16ORF70
# Failed finding:  C1ORF21
# Gene too short:  C1QTNF4
# Gene too short:  CA7
# Gene too short:  CABP1
# Gene too short:  CALB1
# Gene too short:  CAMK2B
# Gene too short:  CBFB
# Gene too short:  CCDC92
# Gene too short:  CCND3
# Gene too short:  CCNDBP1
# Gene too short:  CCNH
# Gene too short:  CD99L2
# Gene too short:  CDKN2C
# Gene too short:  CDO1
# Gene too short:  CHPT1
# Gene too short:  CHST11
# Gene too short:  CITED2
# Gene too short:  CNIH4
# Gene too short:  CNN3
# Gene too short:  CNOT7
# Gene too short:  CNRIP1
# Gene too short:  COMMD6
# Gene too short:  COPS7B
# Gene too short:  COPS8
# Gene too short:  CRH
# Gene too short:  CYB561
# Gene too short:  CYB5B
# Gene too short:  DBNDD2
# Gene too short:  DCUN1D1
# Gene too short:  DHDDS
# Gene too short:  DLK2
# Gene too short:  DLX1
# Gene too short:  DLX2
# Gene too short:  DNAJB9
# Gene too short:  DUSP12
# Gene too short:  DYNLL2
# Gene too short:  ECHS1
# Gene too short:  EEF1B2
# Gene too short:  ELOVL1
# Gene too short:  ELOVL5
# Gene too short:  ERH
# Gene too short:  ERLIN2
# Gene too short:  FAM107A
# Gene too short:  FDX1
# Gene too short:  FEZ1
# Gene too short:  FNDC4
# Gene too short:  FNDC5
# Gene too short:  FOSL2
# Gene too short:  FOXN2
# Gene too short:  GMFB
# Gene too short:  GOLGA7
# Gene too short:  GSG1L
# Gene too short:  GSTK1
# Gene too short:  GTF3C6
# Gene too short:  HADH
# Gene too short:  HINT3
# Gene too short:  HMGB3
# Gene too short:  HNRNPA0
# Gene too short:  HPCA
# Gene too short:  HTATIP2
# Gene too short:  ID4
# Gene too short:  ING2
# Gene too short:  ING5
# Gene too short:  KCNJ3
# Gene too short:  KCTD1
# Gene too short:  KCTD12
# Gene too short:  KDSR
# Gene too short:  LAMTOR2
# Gene too short:  LASP1
# Gene too short:  LDHA
# Gene too short:  LGALS8
# Gene too short:  LIN52
# Gene too short:  LIX1L
# Gene too short:  LRRC58
# Gene too short:  LSM12
# Gene too short:  LZTFL1
# Gene too short:  LZTS1
# Gene too short:  MAFF
# Gene too short:  MANBAL
# Gene too short:  MBLAC2
# Gene too short:  MDFIC
# Gene too short:  MDM4
# Gene too short:  MED28
# Gene too short:  MLEC
# Gene too short:  MLF1
# Gene too short:  MTCH1
# Gene too short:  MXRA7
# Gene too short:  NAIF1
# Gene too short:  NDEL1
# Gene too short:  NDUFA6
# Gene too short:  NDUFB10
# Gene too short:  NDUFB9
# Gene too short:  NDUFS6
# Gene too short:  NECAP1
# Gene too short:  NEK7
# Gene too short:  NFE2L1
# Gene too short:  NPTN
# Gene too short:  NR2F6
# Gene too short:  NUS1
# Gene too short:  NXT2
# Gene too short:  OPRM1
# Gene too short:  OSTF1
# Gene too short:  OSTM1
# Gene too short:  OTUD1
# Gene too short:  PACRGL
# Gene too short:  PAFAH1B2
# Gene too short:  PALM2
# Gene too short:  PARP11
# Gene too short:  PCGF3
# Gene too short:  PDCL3
# Gene too short:  PDXK
# Gene too short:  PEX11B
# Gene too short:  PGP
# Gene too short:  PGRMC1
# Gene too short:  PHC2
# Gene too short:  PLCXD3
# Gene too short:  PLEKHA3
# Gene too short:  PLEKHB1
# Gene too short:  PMEPA1
# Gene too short:  PPP1R7
# Gene too short:  PTS
# Gene too short:  PTTG1IP
# Gene too short:  QDPR
# Gene too short:  RAB27A
# Gene too short:  RAB31
# Gene too short:  RAB39B
# Gene too short:  RAB3B
# Gene too short:  RAB4A
# Gene too short:  RAB8B
# Gene too short:  RALYL
# Gene too short:  RAP1B
# Gene too short:  RASD2
# Gene too short:  RBM18
# Gene too short:  RCAN2
# Gene too short:  REEP3
# Gene too short:  RELL1
# Gene too short:  RFK
# Gene too short:  RGS17
# Gene too short:  RHOG
# Gene too short:  RILPL2
# Gene too short:  RIT1
# Gene too short:  RNF115
# Gene too short:  RNF141
# Gene too short:  RNF217
# Gene too short:  RPL10A
# Gene too short:  RPL11
# Gene too short:  RPL19
# Gene too short:  RPL35A
# Gene too short:  RPLP2
# Gene too short:  RPS2
# Gene too short:  RPS21
# Gene too short:  RPS25
# Gene too short:  RPS26
# Gene too short:  SAMD12
# Gene too short:  SCOC
# Gene too short:  SCRG1
# Gene too short:  SERTAD4
# Gene too short:  SF3B4
# Gene too short:  SF3B5
# Gene too short:  SFXN3
# Gene too short:  SNAPC3
# Gene too short:  SOSTDC1
# Gene too short:  SPAG7
# Gene too short:  SPRY2
# Gene too short:  ST8SIA3
# Gene too short:  SUMF2
# Gene too short:  SYNDIG1L
# Gene too short:  TEF
# Gene too short:  TFEB
# Gene too short:  TMED5
# Gene too short:  TMEM123
# Gene too short:  TMEM170B
# Gene too short:  TMEM65
# Gene too short:  TMX4
# Gene too short:  TTC19
# Gene too short:  TTC9
# Gene too short:  UBE2K
# Gene too short:  UCHL1
# Gene too short:  USE1
# Gene too short:  VAMP1
# Gene too short:  VBP1
# Gene too short:  VMA21
# Gene too short:  VSTM2A
# Gene too short:  WIPF2
# Gene too short:  YAF2
# Gene too short:  YPEL2
# Gene too short:  YPEL5
# Gene too short:  ZDHHC2
# Failed finding:  ABLIM2
# Failed finding:  ACAA2
# Failed finding:  ACVR2A
# Failed finding:  ADD3
# Failed finding:  ADSSL1
# Failed finding:  AGTPBP1
# Failed finding:  ALDH3A2
# Failed finding:  ALDH9A1
# Failed finding:  ANAPC4
# Failed finding:  ANKMY2
# Failed finding:  ANKRD11
# Failed finding:  ARHGAP32
# Failed finding:  ARID2
# Failed finding:  ARL5B
# Failed finding:  ASPA
# Failed finding:  ATP11B
# Failed finding:  ATP5G2
# Failed finding:  ATXN1L
# Failed finding:  ATXN7
# Failed finding:  B3GALTL
# Failed finding:  BAIAP2
# Failed finding:  BBS7
# Failed finding:  BBX
# Failed finding:  BECN1
# Failed finding:  BID
# Failed finding:  BLOC1S5
# Failed finding:  BMI1
# Failed finding:  BRE
# Failed finding:  BTRC
# Failed finding:  C16ORF52
# Gene too short:  CACYBP
# Failed finding:  CAND1
# Failed finding:  CASP2
# Failed finding:  CASP8AP2
# Failed finding:  CBL
# Failed finding:  CBLL1
# Failed finding:  CBLN1
# Failed finding:  CCDC88C
# Gene too short:  CCK
# Failed finding:  CDC14B
# Gene too short:  CDC26
# Failed finding:  CDK12
# Failed finding:  CDK5RAP2
# Failed finding:  CHM
# Failed finding:  CHMP2A
# Failed finding:  CHSY1
# Failed finding:  CLASP1
# Failed finding:  CLDN11
# Failed finding:  CNKSR2
# Failed finding:  CNOT6L
# Failed finding:  CNOT8
# Failed finding:  CNTN1
# Failed finding:  COMT
# Gene too short:  COX6A1
# Failed finding:  CPD
# Failed finding:  CPOX
# Failed finding:  CTDSPL
# Failed finding:  CTDSPL2
# Failed finding:  CTSC
# Failed finding:  CXADR
# Gene too short:  DCTN3
# Failed finding:  DDX24
# Failed finding:  DEF8
# Failed finding:  DENND5A
# Failed finding:  DHX30
# Failed finding:  DMXL2
# Failed finding:  DNAJC2
# Failed finding:  DNAJC3
# Failed finding:  DNTTIP2
# Failed finding:  DOCK10
# Failed finding:  DPY19L3
# Failed finding:  DTNA
# Failed finding:  DTNB
# Failed finding:  EEF1G
# Failed finding:  EGR2
# Failed finding:  EGR3
# Failed finding:  EIF6
# Failed finding:  EML5
# Failed finding:  ESYT2
# Failed finding:  EVL
# Failed finding:  FAM105A
# Failed finding:  FAM122B
# Failed finding:  FAM134C
# Failed finding:  FAM177A1
# Failed finding:  FAM199X
# Failed finding:  FAM3C
# Failed finding:  FAR1
# Failed finding:  FBXO21
# Failed finding:  FBXO33
# Failed finding:  FGD4
# Failed finding:  FHL2
# Failed finding:  FOXP1
# Failed finding:  GABRB2
# Failed finding:  GABRG2
# Failed finding:  GADD45B
# Failed finding:  GBA
# Gene too short:  GJB1
# Failed finding:  GNB5
# Failed finding:  GOSR2
# Failed finding:  GPR88
# Gene too short:  GPX4
# Failed finding:  GRAMD3
# Gene too short:  GRB2
# Failed finding:  GRIK5
# Failed finding:  GRM4
# Gene too short:  H3F3A
# Failed finding:  HDAC8
# Failed finding:  HEBP1
# Failed finding:  HECTD1
# Failed finding:  HEXDC
# Failed finding:  HIBCH
# Failed finding:  HIGD2A
# Failed finding:  HIPK3
# Failed finding:  HMGN2
# Failed finding:  HS2ST1
# Failed finding:  HS6ST2
# Failed finding:  HSPD1
# Failed finding:  IFNAR2
# Failed finding:  IFNGR1
# Failed finding:  IKZF5
# Failed finding:  INPP5F
# Failed finding:  INTS6
# Failed finding:  INTS8
# Failed finding:  IRS4
# Failed finding:  ITGA6
# Failed finding:  ITGB1
# Failed finding:  ITPKA
# Failed finding:  ITPR1
# Failed finding:  JMJD1C
# Failed finding:  KCNAB1
# Failed finding:  KIAA1551
# Failed finding:  KLC1
# Failed finding:  KLHL2
# Failed finding:  KMT2C
# Failed finding:  LACTB
# Failed finding:  LANCL2
# Failed finding:  LGMN
# Failed finding:  LIMS2
# Failed finding:  LRBA
# Failed finding:  MAP2K6
# Failed finding:  MAPK14
# Failed finding:  MAPK8
# Failed finding:  MED17
# Failed finding:  MKL2
# Failed finding:  MLH3
# Failed finding:  MOB1B
# Failed finding:  MRPL48
# Failed finding:  MRPL50
# Failed finding:  MRPS18C
# Failed finding:  MSRA
# Failed finding:  MTDH
# Failed finding:  MTMR3
# Failed finding:  MYO5B
# Failed finding:  MYO9A
# Failed finding:  MYT1L
# Failed finding:  NAA16
# Failed finding:  NCOA7
# Gene too short:  NDFIP1
# Failed finding:  NDUFC1
# Failed finding:  NDUFV3
# Failed finding:  NEBL
# Failed finding:  NEFM
# Failed finding:  NFS1
# Failed finding:  NPEPPS
# Failed finding:  NRBF2
# Failed finding:  NSD1
# Failed finding:  NT5C2
# Gene too short:  NTS
# Failed finding:  NUP210
# Failed finding:  OLA1
# Failed finding:  OSBPL9
# Failed finding:  OTUD6B
# Failed finding:  OXCT1
# Failed finding:  P4HA1
# Failed finding:  PANK1
# Failed finding:  PANX1
# Failed finding:  PARM1
# Failed finding:  PARP1
# Failed finding:  PDCD4
# Failed finding:  PDE8A
# Failed finding:  PDS5A
# Failed finding:  PELI1
# Failed finding:  PER2
# Gene too short:  PFDN1
# Failed finding:  PHC1
# Failed finding:  PITPNC1
# Failed finding:  PKD2
# Failed finding:  PKIA
# Failed finding:  PKIB
# Gene too short:  PLLP
# Failed finding:  PNKD
# Failed finding:  POLDIP3
# Failed finding:  PPP1CA
# Failed finding:  PPP1R2
# Failed finding:  PPP3CB
# Failed finding:  PPP4R4
# Failed finding:  PRDM8
# Failed finding:  PRKCB
# Failed finding:  PRPF38B
# Failed finding:  PRPS1
# Failed finding:  PSEN1
# Gene too short:  PSMG3
# Failed finding:  PTEN
# Failed finding:  PTPN1
# Failed finding:  PTPN5
# Failed finding:  PTPRT
# Failed finding:  PTTG1
# Failed finding:  PUF60
# Gene too short:  PVALB
# Failed finding:  PXK
# Failed finding:  RAP2B
# Failed finding:  RAPGEF6
# Failed finding:  RARB
# Failed finding:  RASA2
# Failed finding:  RASAL2
# Failed finding:  RBBP5
# Gene too short:  RBM8A
# Failed finding:  RIC8B
# Failed finding:  RINT1
# Failed finding:  RNMT
# Failed finding:  ROCK1
# Gene too short:  RPL7
# Failed finding:  RPL7A
# Failed finding:  RPL8
# Gene too short:  RPLP1
# Gene too short:  RPS11
# Gene too short:  RPS15
# Failed finding:  RPS24
# Failed finding:  RPS27A
# Failed finding:  RPS3
# Failed finding:  RPS6KA5
# Gene too short:  RPSA
# Failed finding:  RYBP
# Failed finding:  RYR1
# Failed finding:  SAAL1
# Failed finding:  SAMM50
# Failed finding:  SCN3B
# Failed finding:  SEC61A2
# Failed finding:  SECISBP2L
# Failed finding:  SEMA3D
# Failed finding:  SEMA7A
# Failed finding:  SENP2
# Failed finding:  SERTAD2
# Failed finding:  SETD7
# Failed finding:  SIK1
# Failed finding:  SIPA1L1
# Failed finding:  SLC1A2
# Failed finding:  SLC25A32
# Failed finding:  SLC33A1
# Failed finding:  SLC6A11
# Failed finding:  SMARCA1
# Failed finding:  SMARCC1
# Failed finding:  SMC5
# Failed finding:  SMYD2
# Failed finding:  SNRNP35
# Failed finding:  SNX1
# Failed finding:  SNX25
# Gene too short:  SOD1
# Failed finding:  SPG21
# Failed finding:  SPRY3
# Failed finding:  SRGAP2
# Failed finding:  SRPK2
# Failed finding:  SSBP2
# Failed finding:  SST
# Failed finding:  SSTR4
# Failed finding:  ST3GAL5
# Failed finding:  STAG1
# Failed finding:  STK40
# Failed finding:  STX1A
# Failed finding:  SURF4
# Failed finding:  SYNJ2BP
# Failed finding:  TADA2A
# Failed finding:  TAF1
# Failed finding:  TBC1D7
# Failed finding:  TCTN3
# Failed finding:  TECR
# Failed finding:  TENM2
# Failed finding:  TGFBR1
# Failed finding:  THAP11
# Failed finding:  TIAM2
# Gene too short:  TIMM17A
# Gene too short:  TIMM9
# Failed finding:  TJP1
# Failed finding:  TMEM141
# Failed finding:  TMEM151B
# Failed finding:  TMEM214
# Gene too short:  TMEM41A
# Failed finding:  TMEM88
# Failed finding:  TMOD3
# Failed finding:  TMX1
# Failed finding:  TNRC18
# Failed finding:  TNRC6B
# Failed finding:  TOMM70A
# Failed finding:  TOP1
# Failed finding:  TPST1
# Failed finding:  TRAPPC8
# Failed finding:  TRHDE
# Failed finding:  TRIB1
# Failed finding:  TRIM37
# Failed finding:  TRIM59
# Gene too short:  TTR
# Failed finding:  TUBB2A
# Failed finding:  UBE2F
# Failed finding:  UBE2Q2
# Failed finding:  UBE2W
# Failed finding:  UHRF2
# Failed finding:  UNC13A
# Failed finding:  UTRN
# Failed finding:  VCL
# Failed finding:  WDFY1
# Failed finding:  WDR44
# Failed finding:  WDR47
# Failed finding:  WHSC1
# Failed finding:  WSB1
# Failed finding:  WWP1
# Failed finding:  XIAP
# Failed finding:  XPC
# Failed finding:  XPNPEP3
# Failed finding:  YTHDC2
# Failed finding:  ZBTB44
# Failed finding:  ZC3H13
# Failed finding:  ZCCHC6
# Failed finding:  ZFP462
# Failed finding:  ZFYVE16
# Failed finding:  ZNF638
# Failed finding:  ZZZ3
# Failed finding:  GFP
# {'spreadsheetId': '1JWkq1Zhi5N5DVEd45lAkYONL564Y5cF8mHoYzsxWFws',
#  'updatedRange': 'Sheet1!F2:F3000',
#  'updatedRows': 2999,
#  'updatedColumns': 1,
#  'updatedCells': 2999}

# %%
# Add info to spreadsheet
# WARNING - you must figure out column numbers and change bits for new gene sets
gene_annotations = ensymbl_to_geneinfo(expression_worksheet.range('F2:F205'), '/home/zach/Documents/Untitled Folder/mouse_gene_info2.txt', organism='mouse')
gname = expression_worksheet.range('F2:F189')
tname = expression_worksheet.range('G2:G189')
length = expression_worksheet.range('D2:D189')
descript = expression_worksheet.range('B2:B189')
gene = expression_worksheet.range('A2:A189')
update = []
for idx, g in enumerate(gene_annotations):
    info = g[1]
    if info is None:
        continue
    max_transcript = info['Transcript stable ID'].iloc[0]
    max_length = info['Transcript length (including UTRs and CDS)'].iloc[0]
    descript_val = info['Gene description'].iloc[0]
    gene_name = info['Gene name'].iloc[0]
    tname[idx].value = max_transcript
    length[idx].value = str(max_length)
    descript[idx].value = str(descript_val)
    gene[idx].value = str(gene_name)
expression_worksheet.update_cells(tname)
expression_worksheet.update_cells(length)
expression_worksheet.update_cells(descript)
expression_worksheet.update_cells(gene)
# Out:
# Gene too short:  ENSMUSG00000046259
# Gene too short:  ENSMUSG00000048455
# Gene too short:  ENSMUSG00000056054
# Gene too short:  ENSMUSG00000044303
# Gene too short:  ENSMUSG00000049775
# Gene too short:  ENSMUSG00000001131
# Gene too short:  ENSMUSG00000056071
# {'spreadsheetId': '11MMvEY4s8oUIGf5kyoA4QOKs-Br2myyNooNmSO7-nEU',
#  'updatedCells': 188,
#  'updatedColumns': 1,
#  'updatedRange': 'Sheet1!A2:A189',
#  'updatedRows': 188}

# %%
readout_names = ['RS0095', 'RS0109', 'RS0175', 'RS0237', 'RS0307', 'RS0332', 'RS0384', 'RS0406', 
                'RS0451', 'RS0468', 'RS0548', 'RS64.0', 'RS156.0', 'RS278.0', 'RS313.0', 'RS643.0', 
                'RS740.0', 'RS810.0']
def write_codebook(rows, fname, readout_names, codebook_style = '148MHD4'):
    with open(fname, 'w') as f:
        f.write('version'+','+str(1)+'\n')
        f.write('codebook_name'+','+codebook_style+'\n')
        f.write('bit_names,'+','.join(readout_names)+'\n')
        f.write('name, id, barcode\n')
        for row in rows:
            f.write(','.join([row[0], row[1], row[2]+'\n']))

# %%
# Generate Codebook
row_tuples = []

for idx, row in expression_df.drop_duplicates('Transcript_ID').iterrows():
    row_tuples.append((row['Gene'], row['Transcript_ID'].split('.')[0], str(row['Barcode'])))

write_codebook(row_tuples, '/bigstore/GeneralStorage/Zach/MERFISH/Probe_Design/MERFISH_analysis-master/finch/Zebra_Finch_Codebook.txt', readout_names)
row_tuples
# Out:
# [('ABAT', 'ENSTGUT00000004827', '101000000001000001'),
#  ('ABHD12', 'ENSTGUT00000005204', '10000110100'),
#  ('ABHD5', 'ENSTGUT00000003977', '1001000110'),
#  ('ACOX1', 'ENSTGUT00000008556', '11101000000000000'),
#  ('ACSL4', 'ENSTGUT00000004521', '1000000110001000'),
#  ('ACTN1', 'ENSTGUT00000011968', '100001010100000'),
#  ('ACVR1', 'ENSTGUT00000012693', '10000000100101000'),
#  ('ADAM10', 'ENSTGUT00000006342', '10000011000001'),
#  ('ADAM17', 'ENSTGUT00000013573', '1001101000000000'),
#  ('ADAM9', 'ENSTGUT00000005272', '101000101'),
#  ('ADPGK', 'ENSTGUT00000004352', '100010000010000010'),
#  ('ADSL', 'ENSTGUT00000010552', '10000110000000100'),
#  ('AFF1', 'ENSTGUT00000002847', '10100000000001010'),
#  ('AFF4', 'ENSTGUT00000000195', '100001000000101'),
#  ('AFTPH', 'ENSTGUT00000002399', '100000100001001'),
#  ('AGFG1', 'ENSTGUT00000008594', '10000010100100'),
#  ('AGRN', 'ENSTGUT00000004205', '100111000000000'),
#  ('AHCYL1', 'ENSTGUT00000000873', '110000101000'),
#  ('AHI1', 'ENSTGUT00000011972', '10010000110000000'),
#  ('AKT3', 'ENSTGUT00000008580', '11000001000010000'),
#  ('ALCAM', 'ENSTGUT00000014176', '1100100100000000'),
#  ('ALDH5A1', 'ENSTGUT00000006725', '1001000011000000'),
#  ('ALS2', 'ENSTGUT00000010664', '101000001010000000'),
#  ('AMD1', 'ENSTGUT00000012549', '10000000001100010'),
#  ('AMER2', 'ENSTGUT00000011942', '10001001100000000'),
#  ('ANGEL1', 'ENSTGUT00000012771', '101110000000000000'),
#  ('ANK2', 'ENSTGUT00000001892', '11000000000011'),
#  ('ANKIB1', 'ENSTGUT00000001531', '1100000010000010'),
#  ('ANKRD13C', 'ENSTGUT00000010715', '1100100001'),
#  ('ANKRD40', 'ENSTGUT00000009592', '1000001000101000'),
#  ('ANKRD44', 'ENSTGUT00000011051', '1000000010000101'),
#  ('ANKRD46', 'ENSTGUT00000012563', '100010001100000'),
#  ('ANO6', 'ENSTGUT00000006289', '10100011'),
#  ('AP3S1', 'ENSTGUT00000018227', '10000000010001001'),
#  ('APBA1', 'ENSTGUT00000001113', '100000101000100000'),
#  ('APBA2', 'ENSTGUT00000005856', '10100000000110000'),
#  ('APOO', 'ENSTGUT00000007577', '1100000001010000'),
#  ('APTX', 'ENSTGUT00000001501', '100010000000110000'),
#  ('ARF1', 'ENSTGUT00000000239', '1010100000000010'),
#  ('ARFGAP3', 'ENSTGUT00000012749', '100000011000010000'),
#  ('ARHGAP17', 'ENSTGUT00000006511', '111000010000000'),
#  ('ARHGAP5', 'ENSTGUT00000012399', '101000000000100100'),
#  ('ARHGDIB', 'ENSTGUT00000009607', '100000000010001100'),
#  ('ARHGEF3', 'ENSTGUT00000007451', '100000001011'),
#  ('ARHGEF6', 'ENSTGUT00000002219', '1011000000100'),
#  ('ARHGEF9', 'ENSTGUT00000005863', '1000010101000'),
#  ('ARID4B', 'ENSTGUT00000010692', '10000001000100100'),
#  ('ARL8B', 'ENSTGUT00000010748', '100000000011010000'),
#  ('ARMC1', 'ENSTGUT00000011726', '10010000000001100'),
#  ('ARMC8', 'ENSTGUT00000007344', '10000100100000010'),
#  ('ARPP21', 'ENSTGUT00000001779', '10100100000001'),
#  ('ARRB1', 'ENSTGUT00000014131', '10000010101000000'),
#  ('ARRDC3', 'ENSTGUT00000000733', '1010000000001001'),
#  ('ARX', 'ENSTGUT00000007374', '10110000100'),
#  ('ASAP1', 'ENSTGUT00000013046', '10011010000000'),
#  ('ASB8', 'ENSTGUT00000003681', '11001000100000'),
#  ('ASIC4', 'ENSTGUT00000006413', '10110000000000001'),
#  ('ASPH', 'ENSTGUT00000011702', '1000001000000011'),
#  ('ASRGL1', 'ENSTGUT00000013232', '110000010000000010'),
#  ('ATF6', 'ENSTGUT00000017739', '10001001001000'),
#  ('ATG5', 'ENSTGUT00000012704', '1101001'),
#  ('ATP11A', 'ENSTGUT00000009384', '1000000101000010'),
#  ('ATP1B3', 'ENSTGUT00000008788', '1000000100010100'),
#  ('ATP2B1', 'ENSTGUT00000008488', '11010010000000000'),
#  ('ATP6V1B2', 'ENSTGUT00000017981', '101000100000001000'),
#  ('ATP6V1C1', 'ENSTGUT00000012641', '1000100001000100'),
#  ('ATP6V1H', 'ENSTGUT00000011465', '10000000100010001'),
#  ('ATP8A1', 'ENSTGUT00000008927', '1010001010000'),
#  ('ATPAF1', 'ENSTGUT00000008745', '1011100'),
#  ('ATRX', 'ENSTGUT00000006171', '100100100010000000'),
#  ('AZI2', 'ENSTGUT00000003707', '1010010100'),
#  ('B3GLCT', 'ENSTGUT00000012224', '100000000000101010'),
#  ('B4GALT1', 'ENSTGUT00000001523', '101001000010000'),
#  ('B4GALT5', 'ENSTGUT00000009134', '110110000'),
#  ('BACE1', 'ENSTGUT00000000193', '10000001101'),
#  ('BACE2', 'ENSTGUT00000005525', '100010010000000100'),
#  ('BACH1', 'ENSTGUT00000014147', '11000000000000110'),
#  ('BAG1', 'ENSTGUT00000008530', '1100100100000'),
#  ('BASP1', 'ENSTGUT00000007558', '110010000010000'),
#  ('BAZ1A', 'ENSTGUT00000012434', '10101000010000'),
#  ('BAZ2B', 'ENSTGUT00000012753', '100001000000001001'),
#  ('BBS2', 'ENSTGUT00000006826', '10000000011010'),
#  ('BBS4', 'ENSTGUT00000004368', '1001110000'),
#  ('BBS9', 'ENSTGUT00000005515', '100010000100001000'),
#  ('BCAP29', 'ENSTGUT00000003252', '1010010000001'),
#  ('BCKDHB', 'ENSTGUT00000013092', '10011000000010000'),
#  ('BCL11A', 'ENSTGUT00000007051', '11000000010100000'),
#  ('BCL11B', 'ENSTGUT00000013231', '1000011001000000'),
#  ('BCL7B', 'ENSTGUT00000003181', '1100010000000100'),
#  ('BET1L', 'ENSTGUT00000007163', '110001000001'),
#  ('BHLHE41', 'ENSTGUT00000012735', '100010000110'),
#  ('BICC1', 'ENSTGUT00000005823', '100100011000'),
#  ('BICD1', 'ENSTGUT00000011967', '1000110010000000'),
#  ('BRD7', 'ENSTGUT00000008845', '110000000101000'),
#  ('BRPF3', 'ENSTGUT00000001684', '10010010010'),
#  ('BRWD3', 'ENSTGUT00000002668', '11000100000000001'),
#  ('BTAF1', 'ENSTGUT00000009417', '100000010010100000'),
#  ('BTBD10', 'ENSTGUT00000016579', '100000111000000'),
#  ('BTBD3', 'ENSTGUT00000002576', '101010000001'),
#  ('BTBD6', 'ENSTGUT00000013463', '101001010000000000'),
#  ('C16ORF70', '', '1000100000110000'),
#  ('C1GALT1', 'ENSTGUT00000001732', '1000010100100000'),
#  ('C1QTNF4', 'ENSTGUT00000010775', '101000000001000001'),
#  ('CA7', 'ENSTGUT00000010124', '10000110100'),
#  ('CABLES1', 'ENSTGUT00000010822', '1001000110'),
#  ('CABP1', 'ENSTGUT00000010019', '11101000000000000'),
#  ('CACNA1B', 'ENSTGUT00000003176', '1000000110001000'),
#  ('CACNA1H', 'ENSTGUT00000007286', '100001010100000'),
#  ('CACNA2D3', 'ENSTGUT00000007280', '10000000100101000'),
#  ('CADPS2', 'ENSTGUT00000004647', '10000011000001'),
#  ('CALB1', 'ENSTGUT00000012320', '1001101000000000'),
#  ('CAMK2B', 'ENSTGUT00000003620', '101000101'),
#  ('CAMK2G', 'ENSTGUT00000007097', '100010000010000010'),
#  ('CAMK4', 'ENSTGUT00000001036', '10000110000000100'),
#  ('CAPZA1', 'ENSTGUT00000018222', '10100000000001010'),
#  ('CARS', 'ENSTGUT00000009519', '100001000000101'),
#  ('CASC3', 'ENSTGUT00000002395', '100000100001001'),
#  ('CAT', 'ENSTGUT00000005966', '10000010100100'),
#  ('CBFB', 'ENSTGUT00000006933', '100111000000000'),
#  ('CCDC6', 'ENSTGUT00000005733', '110000101000'),
#  ('CCDC88A', 'ENSTGUT00000007331', '10010000110000000'),
#  ('CCDC92', 'ENSTGUT00000005292', '11000001000010000'),
#  ('CCND3', 'ENSTGUT00000018132', '1100100100000000'),
#  ('CCNDBP1', 'ENSTGUT00000005839', '1001000011000000'),
#  ('CCNH', 'ENSTGUT00000001213', '101000001010000000'),
#  ('CCNT2', 'ENSTGUT00000012212', '10000000001100010'),
#  ('CD99L2', 'ENSTGUT00000004760', '10001001100000000'),
#  ('CDADC1', 'ENSTGUT00000012672', '101110000000000000'),
#  ('CDC23', 'ENSTGUT00000000038', '11000000000011'),
#  ('CDH11', 'ENSTGUT00000010321', '1100000010000010'),
#  ('CDH8', 'ENSTGUT00000009756', '1100100001'),
#  ('CDK19', 'ENSTGUT00000012558', '1000001000101000'),
#  ('CDK8', 'ENSTGUT00000012032', '1000000010000101'),
#  ('CDKL5', 'ENSTGUT00000008088', '100010001100000'),
#  ('CDKN2C', 'ENSTGUT00000009005', '10100011'),
#  ('CDO1', 'ENSTGUT00000018225', '10000000010001001'),
#  ('CDS2', 'ENSTGUT00000004192', '100000101000100000'),
#  ('CEP170', 'ENSTGUT00000008525', '10100000000110000'),
#  ('CEP192', 'ENSTGUT00000009906', '1100000001010000'),
#  ('CETN3', 'ENSTGUT00000000707', '100010000000110000'),
#  ('CFL2', 'ENSTGUT00000012428', '1010100000000010'),
#  ('CFLAR', 'ENSTGUT00000010759', '100000011000010000'),
#  ('CGRRF1', 'ENSTGUT00000013631', '111000010000000'),
#  ('CHD1', 'ENSTGUT00000001271', '101000000000100100'),
#  ('CHPT1', 'ENSTGUT00000011823', '100000000010001100'),
#  ('CHRM2', 'ENSTGUT00000012027', '100000001011'),
#  ('CHRM4', 'ENSTGUT00000011082', '1011000000100'),
#  ('CHST11', 'ENSTGUT00000011598', '1000010101000'),
#  ('CITED2', 'ENSTGUT00000011397', '10000001000100100'),
#  ('CLCN6', 'ENSTGUT00000002473', '100000000011010000'),
#  ('CMAS', 'ENSTGUT00000012564', '10010000000001100'),
#  ('CMTR1', 'ENSTGUT00000008266', '10000100100000010'),
#  ('CNIH4', 'ENSTGUT00000004213', '10100100000001'),
#  ('CNN3', 'ENSTGUT00000005840', '10000010101000000'),
#  ('CNOT1', 'ENSTGUT00000006175', '1010000000001001'),
#  ('CNOT6', 'ENSTGUT00000001170', '10110000100'),
#  ('CNOT7', 'ENSTGUT00000007547', '10011010000000'),
#  ('CNRIP1', 'ENSTGUT00000002467', '11001000100000'),
#  ('CNTN2', 'ENSTGUT00000018180', '10110000000000001'),
#  ('COG2', 'ENSTGUT00000010402', '1000001000000011'),
#  ('COL11A1', 'ENSTGUT00000005199', '110000010000000010'),
#  ('COL4A3BP', 'ENSTGUT00000006399', '10001001001000'),
#  ('COMMD10', 'ENSTGUT00000018232', '1101001'),
#  ('COMMD6', 'ENSTGUT00000013048', '1000000101000010'),
#  ('COPG2', 'ENSTGUT00000002005', '1000000100010100'),
#  ('COPS7B', 'ENSTGUT00000010231', '11010010000000000'),
#  ('COPS8', 'ENSTGUT00000003810', '101000100000001000'),
#  ('CPE', 'ENSTGUT00000006170', '1000100001000100'),
#  ('CPEB3', 'ENSTGUT00000009372', '10000000100010001'),
#  ('CPEB4', 'ENSTGUT00000000343', '1010001010000'),
#  ('CREBRF', 'ENSTGUT00000000324', '1011100'),
#  ('CREM', 'ENSTGUT00000000954', '100100100010000000'),
#  ('CRH', 'ENSTGUT00000011750', '1010010100'),
#  ('CRTC1', 'ENSTGUT00000001108', '100000000000101010'),
#  ('CSE1L', 'ENSTGUT00000009212', '101001000010000'),
#  ('CSGALNACT2', 'ENSTGUT00000006473', '110110000'),
#  ('CSRP1', 'ENSTGUT00000001368', '10000001101'),
#  ('CTNNBL1', 'ENSTGUT00000006463', '100010010000000100'),
#  ('CTSH', 'ENSTGUT00000010401', '11000000000000110'),
#  ('CUL5', 'ENSTGUT00000013172', '1100100100000'),
#  ('CXCR4', 'ENSTGUT00000012314', '110010000010000'),
#  ('CYB561', 'ENSTGUT00000002051', '10101000010000'),
#  ('CYB5B', 'ENSTGUT00000008431', '100001000000001001'),
#  ('CYFIP1', 'ENSTGUT00000010988', '10000000011010'),
#  ('CYLD', 'ENSTGUT00000007850', '1001110000'),
#  ('CYP2U1', 'ENSTGUT00000004158', '100010000100001000'),
#  ('DAAM1', 'ENSTGUT00000013555', '1010010000001'),
#  ('DACH1', 'ENSTGUT00000013005', '10011000000010000'),
#  ('DBNDD2', 'ENSTGUT00000005194', '11000000010100000'),
#  ('DCAF17', 'ENSTGUT00000008554', '1000011001000000'),
#  ('DCBLD2', 'ENSTGUT00000014203', '1100010000000100'),
#  ('DCP1A', 'ENSTGUT00000007094', '110001000001'),
#  ('DCUN1D1', 'ENSTGUT00000010962', '100010000110'),
#  ('DCUN1D4', 'ENSTGUT00000008275', '100100011000'),
#  ('DDB1', 'ENSTGUT00000006714', '1000110010000000'),
#  ('DDHD1', 'ENSTGUT00000013640', '110000000101000'),
#  ('DDIT4', 'ENSTGUT00000004641', '10010010010'),
#  ('DDX10', 'ENSTGUT00000013134', '11000100000000001'),
#  ('DDX47', 'ENSTGUT00000009800', '100000010010100000'),
#  ('DDX58', 'ENSTGUT00000001581', '100000111000000'),
#  ('DENND4A', 'ENSTGUT00000009660', '101010000001'),
#  ('DENND5B', 'ENSTGUT00000011955', '101001010000000000'),
#  ('DGKB', 'ENSTGUT00000002635', '1000100000110000'),
#  ('DGKH', 'ENSTGUT00000012902', '1000010100100000'),
#  ('DGKI', 'ENSTGUT00000012064', '1001000001010'),
#  ('DHDDS', 'ENSTGUT00000001071', '101000000001000001'),
#  ('DIDO1', 'ENSTGUT00000007914', '10000110100'),
#  ('DIRC2', 'ENSTGUT00000004573', '1001000110'),
#  ('DLG2', 'ENSTGUT00000013497', '11101000000000000'),
#  ('DLGAP2', 'ENSTGUT00000013471', '1000000110001000'),
#  ('DLGAP3', 'ENSTGUT00000001809', '100001010100000'),
#  ('DLK1', 'ENSTGUT00000013308', '10000000100101000'),
#  ('DLK2', 'ENSTGUT00000009477', '10000011000001'),
#  ('DLL4', 'ENSTGUT00000011230', '1001101000000000'),
#  ('DLX1', 'ENSTGUT00000008717', '101000101'),
#  ('DLX2', 'ENSTGUT00000008719', '100010000010000010'),
#  ('DNAJA4', 'ENSTGUT00000003436', '10000110000000100'),
#  ('DNAJB14', 'ENSTGUT00000003636', '10100000000001010'),
#  ('DNAJB9', 'ENSTGUT00000005818', '100001000000101'),
#  ('DNAJC10', 'ENSTGUT00000010002', '100000100001001'),
#  ('DNAJC13', 'ENSTGUT00000004565', '10000010100100'),
#  ('DNAJC16', 'ENSTGUT00000017826', '100111000000000'),
#  ('DNAJC21', 'ENSTGUT00000002049', '110000101000'),
#  ('DRD2', 'ENSTGUT00000000272', '10010000110000000'),
#  ('DRD5', 'ENSTGUT00000010326', '11000001000010000'),
#  ('DUSP12', 'ENSTGUT00000013910', '1100100100000000'),
#  ('DUSP16', 'ENSTGUT00000013233', '1001000011000000'),
#  ('DUSP5', 'ENSTGUT00000011050', '101000001010000000'),
#  ('DUSP6', 'ENSTGUT00000008386', '10000000001100010'),
#  ('DVL3', 'ENSTGUT00000010547', '10001001100000000'),
#  ('DYNC1I2', 'ENSTGUT00000008628', '101110000000000000'),
#  ('DYNC1LI2', 'ENSTGUT00000010197', '11000000000011'),
#  ('DYNLL2', 'ENSTGUT00000008753', '1100000010000010'),
#  ('E2F3', 'ENSTGUT00000006578', '1100100001'),
#  ('E2F6', 'ENSTGUT00000013621', '1000001000101000'),
#  ('ECHS1', 'ENSTGUT00000005022', '1000000010000101'),
#  ('EDEM1', 'ENSTGUT00000010785', '100010001100000'),
#  ('EEF1B2', 'ENSTGUT00000010374', '10100011'),
#  ('EFNB2', 'ENSTGUT00000011255', '10000000010001001'),
#  ('EFR3A', 'ENSTGUT00000013056', '100000101000100000'),
#  ('EIF2B3', 'ENSTGUT00000008104', '10100000000110000'),
#  ('EIF4A3', 'ENSTGUT00000002224', '1100000001010000'),
#  ('EIF4G1', 'ENSTGUT00000010750', '100010000000110000'),
#  ('EIF5', 'ENSTGUT00000013378', '1010100000000010'),
#  ('ELAVL1', 'ENSTGUT00000000123', '100000011000010000'),
#  ('ELAVL2', 'ENSTGUT00000001410', '111000010000000'),
#  ('ELF1', 'ENSTGUT00000012950', '101000000000100100'),
#  ('ELFN1', 'ENSTGUT00000015949', '100000000010001100'),
#  ('ELK4', 'ENSTGUT00000018202', '100000001011'),
#  ('ELMO2', 'ENSTGUT00000005959', '1011000000100'),
#  ('ELOVL1', 'ENSTGUT00000007472', '1000010101000'),
#  ('ELOVL5', 'ENSTGUT00000013397', '10000001000100100'),
#  ('ELP4', 'ENSTGUT00000005003', '100000000011010000'),
#  ('EML1', 'ENSTGUT00000013267', '10010000000001100'),
#  ('ENO2', 'ENSTGUT00000013842', '10000100100000010'),
#  ('EPB41L2', 'ENSTGUT00000012188', '10100100000001'),
#  ('EPHA7', 'ENSTGUT00000012862', '10000010101000000'),
#  ('EPS15L1', 'ENSTGUT00000000720', '1010000000001001'),
#  ('EPS8', 'ENSTGUT00000012915', '10110000100'),
#  ('ERC2', 'ENSTGUT00000007364', '10011010000000'),
#  ('ERH', 'ENSTGUT00000011923', '11001000100000'),
#  ('ERLIN2', 'ENSTGUT00000004833', '10110000000000001'),
#  ('ERMP1', 'ENSTGUT00000005202', '1000001000000011'),
#  ('ERP44', 'ENSTGUT00000009194', '110000010000000010'),
#  ('ESF1', 'ENSTGUT00000002545', '10001001001000'),
#  ('ETF1', 'ENSTGUT00000015349', '1101001'),
#  ('ETFA', 'ENSTGUT00000003704', '1000000101000010'),
#  ('EVI5', 'ENSTGUT00000006281', '1000000100010100'),
#  ('EXD2', 'ENSTGUT00000011951', '11010010000000000'),
#  ('EXOC6', 'ENSTGUT00000009282', '101000100000001000'),
#  ('EXOC7', 'ENSTGUT00000008407', '1000100001000100'),
#  ('EZR', 'ENSTGUT00000011516', '10000000100010001'),
#  ('FA2H', 'ENSTGUT00000006575', '1010001010000'),
#  ('FAF2', 'ENSTGUT00000000552', '1011100'),
#  ('FAM107A', 'ENSTGUT00000009635', '100100100010000000'),
#  ('FAM110B', 'ENSTGUT00000011584', '1010010100'),
#  ('FAM114A2', 'ENSTGUT00000000742', '100000000000101010'),
#  ('FAM118B', 'ENSTGUT00000000857', '101001000010000'),
#  ('FAM126B', 'ENSTGUT00000010783', '110110000'),
#  ('FAM184A', 'ENSTGUT00000012365', '10000001101'),
#  ('FAM192A', 'ENSTGUT00000005390', '100010010000000100'),
#  ('FAM20B', 'ENSTGUT00000018077', '11000000000000110'),
#  ('FAM49A', 'ENSTGUT00000013651', '1100100100000'),
#  ('FAM98A', 'ENSTGUT00000009434', '110010000010000'),
#  ('FARSB', 'ENSTGUT00000008154', '10101000010000'),
#  ('FAXC', 'ENSTGUT00000012797', '100001000000001001'),
#  ('FBXO11', 'ENSTGUT00000005834', '10000000011010'),
#  ('FBXO3', 'ENSTGUT00000005843', '1001110000'),
#  ('FBXO30', 'ENSTGUT00000011232', '100010000100001000'),
#  ('FBXO34', 'ENSTGUT00000013616', '1010010000001'),
#  ('FBXO9', 'ENSTGUT00000013405', '10011000000010000'),
#  ('FBXW2', 'ENSTGUT00000007793', '11000000010100000'),
#  ('FCHO2', 'ENSTGUT00000006055', '1000011001000000'),
#  ('FDX1', 'ENSTGUT00000011734', '1100010000000100'),
#  ('FEZ1', 'ENSTGUT00000000765', '110001000001'),
#  ('FGD6', 'ENSTGUT00000008757', '100010000110'),
#  ('FGFR1OP', 'ENSTGUT00000009954', '100100011000'),
#  ('FIGN', 'ENSTGUT00000007246', '1000110010000000'),
#  ('FLRT3', 'ENSTGUT00000002531', '110000000101000'),
#  ('FNBP1', 'ENSTGUT00000004741', '10010010010'),
#  ('FNBP1L', 'ENSTGUT00000006142', '11000100000000001'),
#  ('FNDC4', 'ENSTGUT00000015267', '100000010010100000'),
#  ('FNDC5', 'ENSTGUT00000001393', '100000111000000'),
#  ('FNIP2', 'ENSTGUT00000005927', '101010000001'),
#  ('FOSL2', 'ENSTGUT00000002654', '101001010000000000'),
#  ('FOXJ2', 'ENSTGUT00000013682', '1000100000110000'),
#  ('FOXN2', 'ENSTGUT00000005837', '1000010100100000'),
#  ('FOXO1', 'ENSTGUT00000012505', '1001000001010'),
#  ('FRMD4A', 'ENSTGUT00000002409', '101000000001000001'),
#  ('FRYL', 'ENSTGUT00000008387', '10000110100'),
#  ('FUBP1', 'ENSTGUT00000007182', '1001000110'),
#  ('FUCA1', 'ENSTGUT00000001242', '11101000000000000'),
#  ('GAB1', 'ENSTGUT00000002496', '1000000110001000'),
#  ('GABBR2', 'ENSTGUT00000008895', '100001010100000'),
#  ('GABRA1', 'ENSTGUT00000001517', '10000000100101000'),
#  ('GABRA4', 'ENSTGUT00000008716', '10000011000001'),
#  ('GABRA5', 'ENSTGUT00000010850', '1001101000000000'),
#  ('GALNT1', 'ENSTGUT00000008394', '101000101'),
#  ('GALNT7', 'ENSTGUT00000006490', '100010000010000010'),
#  ('GALNTL6', 'ENSTGUT00000006466', '10000110000000100'),
#  ('GAP43', 'ENSTGUT00000013958', '10100000000001010'),
#  ('GARS', 'ENSTGUT00000000383', '100001000000101'),
#  ('GATAD1', 'ENSTGUT00000001535', '100000100001001'),
#  ('GBF1', 'ENSTGUT00000007775', '10000010100100'),
#  ('GCLC', 'ENSTGUT00000013394', '100111000000000'),
#  ('GDA', 'ENSTGUT00000000860', '110000101000'),
#  ('GDAP1', 'ENSTGUT00000012057', '10010000110000000'),
#  ('GFM2', 'ENSTGUT00000006254', '11000001000010000'),
#  ('GLA', 'ENSTGUT00000006825', '1100100100000000'),
#  ('GLB1', 'ENSTGUT00000004748', '1001000011000000'),
#  ('GLCCI1', 'ENSTGUT00000001749', '101000001010000000'),
#  ('GLRA2', 'ENSTGUT00000008494', '10000000001100010'),
#  ('GLS', 'ENSTGUT00000011286', '10001001100000000'),
#  ('GLYR1', 'ENSTGUT00000003269', '101110000000000000'),
#  ('GMFB', 'ENSTGUT00000013634', '11000000000011'),
#  ('GNAI2', 'ENSTGUT00000006756', '1100000010000010'),
#  ('GNAL', 'ENSTGUT00000010130', '1100100001'),
#  ('GOLGA1', 'ENSTGUT00000007541', '1000001000101000'),
#  ('GOLGA7', 'ENSTGUT00000005388', '1000000010000101'),
#  ('GOLIM4', 'ENSTGUT00000011525', '100010001100000'),
#  ('GOT1', 'ENSTGUT00000009814', '10100011'),
#  ('GOT2', 'ENSTGUT00000006207', '10000000010001001'),
#  ('GPATCH2', 'ENSTGUT00000002973', '100000101000100000'),
#  ('GPD2', 'ENSTGUT00000012671', '10100000000110000'),
#  ('GPM6A', 'ENSTGUT00000006617', '1100000001010000'),
#  ('GPR158', 'ENSTGUT00000001206', '100010000000110000'),
#  ('GPR75', 'ENSTGUT00000007545', '1010100000000010'),
#  ('GPS1', 'ENSTGUT00000003845', '100000011000010000'),
#  ('GRIA1', 'ENSTGUT00000000768', '111000010000000'),
#  ('GRIA4', 'ENSTGUT00000013212', '101000000000100100'),
#  ('GRID1', 'ENSTGUT00000005868', '100000000010001100'),
#  ('GRIK2', 'ENSTGUT00000012764', '100000001011'),
#  ('GRIN2B', 'ENSTGUT00000009866', '1011000000100'),
#  ('GSG1L', 'ENSTGUT00000004731', '1000010101000'),
#  ('GSK3B', 'ENSTGUT00000013933', '10000001000100100'),
#  ('GSN', 'ENSTGUT00000006984', '100000000011010000'),
#  ('GSPT1', 'ENSTGUT00000005366', '10010000000001100'),
#  ('GSTK1', 'ENSTGUT00000013756', '10000100100000010'),
#  ('GTF3C6', 'ENSTGUT00000012543', '10100100000001'),
#  ('GXYLT1', 'ENSTGUT00000006032', '10000010101000000'),
#  ('H2AFY', 'ENSTGUT00000001300', '1010000000001001'),
#  ('HACL1', 'ENSTGUT00000003173', '10110000100'),
#  ('HADH', 'ENSTGUT00000004166', '10011010000000'),
#  ('HBS1L', 'ENSTGUT00000011998', '11001000100000'),
#  ('HCN2', 'ENSTGUT00000000639', '10110000000000001'),
#  ('HCN4', 'ENSTGUT00000004289', '1000001000000011'),
#  ('HDAC11', 'ENSTGUT00000003969', '110000010000000010'),
#  ('HDAC4', 'ENSTGUT00000003371', '10001001001000'),
#  ('HERC1', 'ENSTGUT00000003345', '1101001'),
#  ('HERC2', 'ENSTGUT00000010936', '1000000101000010'),
#  ('HERPUD1', 'ENSTGUT00000005279', '1000000100010100'),
#  ('HEXB', 'ENSTGUT00000006205', '11010010000000000'),
#  ('HINT3', 'ENSTGUT00000012274', '101000100000001000'),
#  ('HIP1', 'ENSTGUT00000003301', '1000100001000100'),
#  ('HIPK2', 'ENSTGUT00000011876', '10000000100010001'),
#  ('HIVEP2', 'ENSTGUT00000011441', '1010001010000'),
#  ('HMGB3', 'ENSTGUT00000004749', '1011100'),
#  ('HNRNPA0', 'ENSTGUT00000001234', '100100100010000000'),
#  ('HOMER1', 'ENSTGUT00000003868', '1010010100'),
#  ('HPCA', 'ENSTGUT00000018031', '100000000000101010'),
#  ('HRH3', 'ENSTGUT00000008132', '101001000010000'),
#  ('HTATIP2', 'ENSTGUT00000017705', '110110000'),
#  ('HTRA2', 'ENSTGUT00000015272', '10000001101'),
#  ('ICK', 'ENSTGUT00000013407', '100010010000000100'),
#  ('ID4', 'ENSTGUT00000006528', '11000000000000110'),
#  ('IGF2R', 'ENSTGUT00000011936', '1100100100000'),
#  ('IGSF11', 'ENSTGUT00000013955', '110010000010000'),
#  ('IKZF2', 'ENSTGUT00000002997', '10101000010000'),
#  ('ILF3', 'ENSTGUT00000014270', '100001000000001001'),
#  ('IMPAD1', 'ENSTGUT00000011580', '10000000011010'),
#  ('ING2', 'ENSTGUT00000006820', '1001110000'),
#  ('ING5', 'ENSTGUT00000006156', '100010000100001000'),
#  ('INO80D', 'ENSTGUT00000010311', '1010010000001'),
#  ('IPO7', 'ENSTGUT00000008557', '10011000000010000'),
#  ('IPO9', 'ENSTGUT00000001330', '11000000010100000'),
#  ('IQCB1', 'ENSTGUT00000004607', '1000011001000000'),
#  ('IQGAP1', 'ENSTGUT00000010864', '1100010000000100'),
#  ('IQSEC1', 'ENSTGUT00000004055', '110001000001'),
#  ('IQSEC3', 'ENSTGUT00000013182', '100010000110'),
#  ('IREB2', 'ENSTGUT00000003553', '100100011000'),
#  ('ITCH', 'ENSTGUT00000003702', '1000110010000000'),
#  ('ITFG2', 'ENSTGUT00000013697', '110000000101000'),
#  ('ITSN1', 'ENSTGUT00000000542', '10010010010'),
#  ('ITSN2', 'ENSTGUT00000013746', '11000100000000001'),
#  ('JMJD6', 'ENSTGUT00000008129', '100000010010100000'),
#  ('JOSD1', 'ENSTGUT00000010800', '100000111000000'),
#  ('KBTBD11', 'ENSTGUT00000013457', '101010000001'),
#  ('KBTBD2', 'ENSTGUT00000005423', '101001010000000000'),
#  ('KCNA1', 'ENSTGUT00000012453', '1000100000110000'),
#  ('KCNC2', 'ENSTGUT00000007649', '1000010100100000'),
#  ('KCND3', 'ENSTGUT00000014218', '1001000001010'),
#  ('KCNF1', 'ENSTGUT00000013606', '101000000001000001'),
#  ('KCNJ3', 'ENSTGUT00000012657', '10000110100'),
#  ('KCNK2', 'ENSTGUT00000003022', '1001000110'),
#  ('KCNN3', 'ENSTGUT00000004310', '11101000000000000'),
#  ('KCTD1', 'ENSTGUT00000011052', '1000000110001000'),
#  ('KCTD12', 'ENSTGUT00000013066', '100001010100000'),
#  ('KDM2A', 'ENSTGUT00000006232', '10000000100101000'),
#  ('KDSR', 'ENSTGUT00000002120', '10000011000001'),
#  ('KIAA0232', 'ENSTGUT00000010530', '1001101000000000'),
#  ('KIAA1109', 'ENSTGUT00000002063', '101000101'),
#  ('KLF10', 'ENSTGUT00000012627', '100010000010000010'),
#  ('KLHL11', 'ENSTGUT00000002535', '10000110000000100'),
#  ('KNDC1', 'ENSTGUT00000009470', '10100000000001010'),
#  ('KPNA3', 'ENSTGUT00000012644', '100001000000101'),
#  ('KPNA4', 'ENSTGUT00000011634', '100000100001001'),
#  ('KPNA5', 'ENSTGUT00000012424', '10000010100100'),
#  ('KPNA6', 'ENSTGUT00000001443', '100111000000000'),
#  ('LAMTOR2', 'ENSTGUT00000003818', '110000101000'),
#  ('LANCL1', 'ENSTGUT00000011919', '10010000110000000'),
#  ('LASP1', 'ENSTGUT00000002264', '11000001000010000'),
#  ('LCLAT1', 'ENSTGUT00000005605', '1100100100000000'),
#  ('LCMT1', 'ENSTGUT00000006477', '1001000011000000'),
#  ('LCOR', 'ENSTGUT00000010249', '101000001010000000'),
#  ('LDHA', 'ENSTGUT00000009295', '10000000001100010'),
#  ('LDLRAD3', 'ENSTGUT00000010541', '10001001100000000'),
#  ('LGALS8', 'ENSTGUT00000010838', '101110000000000000'),
#  ('LHX8', 'ENSTGUT00000010854', '11000000000011'),
#  ('LIG4', 'ENSTGUT00000011244', '1100000010000010'),
#  ('LIMK1', 'ENSTGUT00000003557', '1100100001'),
#  ('LIN52', 'ENSTGUT00000012608', '1000001000101000'),
#  ('LIPA', 'ENSTGUT00000008691', '1000000010000101'),
#  ('LIX1L', 'ENSTGUT00000004614', '100010001100000'),
#  ('LMO3', 'ENSTGUT00000012895', '10100011'),
#  ('LMTK2', 'ENSTGUT00000009086', '10000000010001001'),
#  ('LONRF1', 'ENSTGUT00000007685', '100000101000100000'),
#  ('LOX', 'ENSTGUT00000001193', '10100000000110000'),
#  ('LPAR1', 'ENSTGUT00000001357', '1100000001010000'),
#  ('LPGAT1', 'ENSTGUT00000003266', '100010000000110000'),
#  ('LPIN1', 'ENSTGUT00000013630', '1010100000000010'),
#  ('LRP6', 'ENSTGUT00000013243', '100000011000010000'),
#  ('LRRC40', 'ENSTGUT00000010762', '111000010000000'),
#  ('LRRC58', 'ENSTGUT00000013931', '101000000000100100'),
#  ('LRRC8C', 'ENSTGUT00000006454', '100000000010001100'),
#  ('LRTM2', 'ENSTGUT00000013106', '100000001011'),
#  ('LSM12', 'ENSTGUT00000014388', '1011000000100'),
#  ('LYSMD2', 'ENSTGUT00000007185', '1000010101000'),
#  ('LZTFL1', 'ENSTGUT00000005389', '10000001000100100'),
#  ('LZTS1', 'ENSTGUT00000017974', '100000000011010000'),
#  ('LZTS3', 'ENSTGUT00000011448', '10010000000001100'),
#  ('MADD', 'ENSTGUT00000010911', '10000100100000010'),
#  ('MAFF', 'ENSTGUT00000010870', '10100100000001'),
#  ('MAML1', 'ENSTGUT00000001088', '10000010101000000'),
#  ('MAN1A2', 'ENSTGUT00000013900', '1010000000001001'),
#  ('MAN2A2', 'ENSTGUT00000010537', '10110000100'),
#  ('MANBAL', 'ENSTGUT00000005124', '10011010000000'),
#  ('MAP2K1', 'ENSTGUT00000009787', '11001000100000'),
#  ('MAP3K4', 'ENSTGUT00000009727', '10110000000000001'),
#  ('MAP3K5', 'ENSTGUT00000011322', '1000001000000011'),
#  ('MAP4K4', 'ENSTGUT00000010358', '110000010000000010'),
#  ('MAPK10', 'ENSTGUT00000002866', '10001001001000'),
#  ('MAPK11', 'ENSTGUT00000004271', '1101001'),
#  ('MAPK9', 'ENSTGUT00000001192', '1000000101000010'),
#  ('MATN1', 'ENSTGUT00000000827', '1000000100010100'),
#  ('MBD5', 'ENSTGUT00000012437', '11010010000000000'),
#  ('MBLAC2', 'ENSTGUT00000000710', '101000100000001000'),
#  ('MBOAT2', 'ENSTGUT00000013543', '1000100001000100'),
#  ('MBP', 'ENSTGUT00000009443', '10000000100010001'),
#  ('MCCC2', 'ENSTGUT00000001596', '1010001010000'),
#  ('MCF2L', 'ENSTGUT00000009467', '1011100'),
#  ('MCMBP', 'ENSTGUT00000011656', '100100100010000000'),
#  ('MDFIC', 'ENSTGUT00000005513', '1010010100'),
#  ('MDM2', 'ENSTGUT00000007133', '100000000000101010'),
#  ('MDM4', 'ENSTGUT00000018170', '101001000010000'),
#  ('MDN1', 'ENSTGUT00000012909', '110110000'),
#  ('MEAF6', 'ENSTGUT00000001622', '10000001101'),
#  ('MED1', 'ENSTGUT00000002295', '100010010000000100'),
#  ('MED13', 'ENSTGUT00000008044', '11000000000000110'),
#  ('MED13L', 'ENSTGUT00000009364', '1100100100000'),
#  ('MED14', 'ENSTGUT00000006881', '110010000010000'),
#  ('MED28', 'ENSTGUT00000010061', '10101000010000'),
#  ('MEF2A', 'ENSTGUT00000009111', '100001000000001001'),
#  ('MEF2C', 'ENSTGUT00000000702', '10000000011010'),
#  ('MEF2D', 'ENSTGUT00000003635', '1001110000'),
#  ('MEIS2', 'ENSTGUT00000012243', '100010000100001000'),
#  ('MEST', 'ENSTGUT00000001974', '1010010000001'),
#  ('MFHAS1', 'ENSTGUT00000005083', '10011000000010000'),
#  ('MFN1', 'ENSTGUT00000011176', '11000000010100000'),
#  ('MIB1', 'ENSTGUT00000010786', '1000011001000000'),
#  ('MICU3', 'ENSTGUT00000007592', '1100010000000100'),
#  ('MIER2', 'ENSTGUT00000000618', '110001000001'),
#  ('MITD1', 'ENSTGUT00000010570', '100010000110'),
#  ('MLEC', 'ENSTGUT00000010028', '100100011000'),
#  ('MLF1', 'ENSTGUT00000011680', '1000110010000000'),
#  ('MLLT10', 'ENSTGUT00000001265', '110000000101000'),
#  ('MNT', 'ENSTGUT00000009135', '10010010010'),
#  ('MPI', 'ENSTGUT00000004073', '11000100000000001'),
#  ('MPP1', 'ENSTGUT00000007123', '100000010010100000'),
#  ('MRPS27', 'ENSTGUT00000005917', '100000111000000'),
#  ('MRPS5', 'ENSTGUT00000002266', '101010000001'),
#  ('MSI2', 'ENSTGUT00000008802', '101001010000000000'),
#  ('MSL3', 'ENSTGUT00000008641', '1000100000110000'),
#  ('MTCH1', 'ENSTGUT00000000976', '1000010100100000'),
#  ('MTM1', 'ENSTGUT00000004838', '1001000001010'),
#  ('MTMR14', 'ENSTGUT00000008893', '101000000001000001'),
#  ('MTUS1', 'ENSTGUT00000007449', '10000110100'),
#  ('MUT', 'ENSTGUT00000013805', '1001000110'),
#  ('MXRA7', 'ENSTGUT00000008147', '11101000000000000'),
#  ('MYEF2', 'ENSTGUT00000007438', '1000000110001000'),
#  ('MYO19', 'ENSTGUT00000008339', '100001010100000'),
#  ('MYO5A', 'ENSTGUT00000006982', '10000000100101000'),
#  ('NAA15', 'ENSTGUT00000002547', '10000011000001'),
#  ('NAE1', 'ENSTGUT00000010144', '1001101000000000'),
#  ('NAIF1', 'ENSTGUT00000003670', '101000101'),
#  ('NAMPT', 'ENSTGUT00000003174', '100010000010000010'),
#  ('NAP1L4', 'ENSTGUT00000009538', '10000110000000100'),
#  ('NAPB', 'ENSTGUT00000007797', '10100000000001010'),
#  ('NAPEPLD', 'ENSTGUT00000002883', '100001000000101'),
#  ('NAV1', 'ENSTGUT00000001353', '100000100001001'),
#  ('NAV2', 'ENSTGUT00000016475', '10000010100100'),
#  ('NAV3', 'ENSTGUT00000007868', '100111000000000'),
#  ('NBEA', 'ENSTGUT00000012346', '110000101000'),
#  ('NCBP1', 'ENSTGUT00000001539', '10010000110000000'),
#  ('NCOA3', 'ENSTGUT00000009399', '11000001000010000'),
#  ('NCOA5', 'ENSTGUT00000006075', '1100100100000000'),
#  ('NDEL1', 'ENSTGUT00000005879', '1001000011000000'),
#  ('NDUFA6', 'ENSTGUT00000010117', '101000001010000000'),
#  ('NDUFB10', 'ENSTGUT00000006956', '10000000001100010'),
#  ('NDUFB9', 'ENSTGUT00000012999', '10001001100000000'),
#  ('NDUFS6', 'ENSTGUT00000008841', '101110000000000000'),
#  ('NECAP1', 'ENSTGUT00000013686', '11000000000011'),
#  ('NEDD4L', 'ENSTGUT00000018176', '1100000010000010'),
#  ('NEFL', 'ENSTGUT00000004664', '1100100001'),
#  ('NEK3', 'ENSTGUT00000012555', '1000001000101000'),
#  ('NEK7', 'ENSTGUT00000004551', '1000000010000101'),
#  ('NELL1', 'ENSTGUT00000004702', '100010001100000'),
#  ('NEO1', 'ENSTGUT00000004338', '10100011'),
#  ('NETO1', 'ENSTGUT00000009581', '10000000010001001'),
#  ('NEUROD6', 'ENSTGUT00000001986', '100000101000100000'),
#  ('NF1', 'ENSTGUT00000008903', '10100000000110000'),
#  ('NFASC', 'ENSTGUT00000018175', '1100000001010000'),
#  ('NFATC3', 'ENSTGUT00000007283', '100010000000110000'),
#  ('NFE2L1', 'ENSTGUT00000015312', '1010100000000010'),
#  ('NFIA', 'ENSTGUT00000010179', '100000011000010000'),
#  ('NFKB1', 'ENSTGUT00000003769', '111000010000000'),
#  ('NFYC', 'ENSTGUT00000018015', '101000000000100100'),
#  ('NGEF', 'ENSTGUT00000007626', '100000000010001100'),
#  ('NIPA2', 'ENSTGUT00000010949', '100000001011'),
#  ('NNT', 'ENSTGUT00000002420', '1011000000100'),
#  ('NOC3L', 'ENSTGUT00000008981', '1000010101000'),
#  ('NONO', 'ENSTGUT00000007350', '10000001000100100'),
#  ('NOVA1', 'ENSTGUT00000012293', '100000000011010000'),
#  ('NPAS2', 'ENSTGUT00000010457', '10010000000001100'),
#  ('NPAS3', 'ENSTGUT00000012410', '10000100100000010'),
#  ('NPAT', 'ENSTGUT00000013157', '10100100000001'),
#  ('NPC1', 'ENSTGUT00000010915', '10000010101000000'),
#  ('NPTN', 'ENSTGUT00000004257', '1010000000001001'),
#  ('NPTX2', 'ENSTGUT00000008998', '10110000100'),
#  ('NR1D2', 'ENSTGUT00000003479', '10011010000000'),
#  ('NR2C2', 'ENSTGUT00000011047', '11001000100000'),
#  ('NR2F6', 'ENSTGUT00000017801', '10110000000000001'),
#  ('NR4A1', 'ENSTGUT00000017487', '1000001000000011'),
#  ('NR4A3', 'ENSTGUT00000009228', '110000010000000010'),
#  ('NRIP1', 'ENSTGUT00000014104', '10001001001000'),
#  ('NTRK2', 'ENSTGUT00000003225', '1101001'),
#  ('NUS1', 'ENSTGUT00000012391', '1000000101000010'),
#  ('NXT2', 'ENSTGUT00000004455', '1000000100010100'),
#  ('OCRL', 'ENSTGUT00000005252', '11010010000000000'),
#  ('OFD1', 'ENSTGUT00000008548', '101000100000001000'),
#  ('OGFOD1', 'ENSTGUT00000006841', '1000100001000100'),
#  ('OGFRL1', 'ENSTGUT00000013235', '10000000100010001'),
#  ('OPA1', 'ENSTGUT00000009550', '1010001010000'),
#  ('OPRL1', 'ENSTGUT00000007601', '1011100'),
#  ('OPRM1', 'ENSTGUT00000011650', '100100100010000000'),
#  ('OSBPL11', 'ENSTGUT00000004140', '1010010100'),
#  ('OSBPL8', 'ENSTGUT00000007772', '100000000000101010'),
#  ('OSTF1', 'ENSTGUT00000000789', '101001000010000'),
#  ('OSTM1', 'ENSTGUT00000012656', '110110000'),
#  ('OTUD1', 'ENSTGUT00000001226', '10000001101'),
#  ('OTUD4', 'ENSTGUT00000002799', '100010010000000100'),
#  ('OTUD7A', 'ENSTGUT00000005674', '11000000000000110'),
#  ('OTUD7B', 'ENSTGUT00000004665', '1100100100000'),
#  ('OXR1', 'ENSTGUT00000012707', '110010000010000'),
#  ('P4HB', 'ENSTGUT00000003633', '10101000010000'),
#  ('PABPC4', 'ENSTGUT00000001325', '100001000000001001'),
#  ('PACRGL', 'ENSTGUT00000009970', '10000000011010'),
#  ('PACSIN2', 'ENSTGUT00000012542', '1001110000'),
#  ('PAFAH1B2', 'ENSTGUT00000000168', '100010000100001000'),
#  ('PALM2', 'ENSTGUT00000001281', '1010010000001'),
#  ('PAN3', 'ENSTGUT00000012114', '10011000000010000'),
#  ('PAPOLG', 'ENSTGUT00000007042', '11000000010100000'),
#  ('PAQR8', 'ENSTGUT00000013825', '1000011001000000'),
#  ('PARD3', 'ENSTGUT00000000979', '1100010000000100'),
#  ('PARG', 'ENSTGUT00000006113', '110001000001'),
#  ('PARP11', 'ENSTGUT00000013715', '100010000110'),
#  ('PARP6', 'ENSTGUT00000004543', '100100011000'),
#  ('PBX3', 'ENSTGUT00000007679', '1000110010000000'),
#  ('PCCB', 'ENSTGUT00000007416', '110000000101000'),
#  ('PCGF3', 'ENSTGUT00000000133', '10010010010'),
#  ('PCSK2', 'ENSTGUT00000002503', '11000100000000001'),
#  ('PCYT1A', 'ENSTGUT00000009888', '100000010010100000'),
#  ('PDCL3', 'ENSTGUT00000010465', '100000111000000'),
#  ('PDE3A', 'ENSTGUT00000012847', '101010000001'),
#  ('PDE3B', 'ENSTGUT00000008832', '101001010000000000'),
#  ('PDE7B', 'ENSTGUT00000011277', '1000100000110000'),
#  ('PDIA5', 'ENSTGUT00000004533', '1000010100100000'),
#  ('PDP1', 'ENSTGUT00000012363', '1001000001010'),
#  ('PDPK1', 'ENSTGUT00000009953', '101000000001000001'),
#  ('PDPR', 'ENSTGUT00000006496', '10000110100'),
#  ('PDS5B', 'ENSTGUT00000012289', '1001000110'),
#  ('PDXK', 'ENSTGUT00000006181', '11101000000000000'),
#  ('PENK', 'ENSTGUT00000011577', '1000000110001000'),
#  ('PEX1', 'ENSTGUT00000001545', '100001010100000'),
#  ('PEX11B', 'ENSTGUT00000004602', '10000000100101000'),
#  ('PEX5', 'ENSTGUT00000013799', '10000011000001'),
#  ('PFKFB3', 'ENSTGUT00000002114', '1001101000000000'),
#  ('PGP', 'ENSTGUT00000016026', '101000101'),
#  ('PGRMC1', 'ENSTGUT00000003444', '100010000010000010'),
#  ('PHACTR1', 'ENSTGUT00000006084', '10000110000000100'),
#  ('PHB2', 'ENSTGUT00000013823', '10100000000001010'),
#  ('PHC2', 'ENSTGUT00000014641', '100001000000101'),
#  ('PHF20', 'ENSTGUT00000003211', '100000100001001'),
#  ('PHF6', 'ENSTGUT00000003087', '10000010100100'),
#  ('PHLDB1', 'ENSTGUT00000000053', '100111000000000'),
#  ('PHLPP1', 'ENSTGUT00000002109', '110000101000'),
#  ('PHLPP2', 'ENSTGUT00000008706', '10010000110000000'),
#  ('PIGS', 'ENSTGUT00000006262', '11000001000010000'),
#  ('PIGU', 'ENSTGUT00000003464', '1100100100000000'),
#  ('PIK3C2A', 'ENSTGUT00000008987', '1001000011000000'),
#  ('PIK3CA', 'ENSTGUT00000011213', '101000001010000000'),
#  ('PIK3R1', 'ENSTGUT00000003143', '10000000001100010'),
#  ('PIP4K2A', 'ENSTGUT00000001246', '10001001100000000'),
#  ('PKM', 'ENSTGUT00000004583', '101110000000000000'),
#  ('PLAA', 'ENSTGUT00000001425', '11000000000011'),
#  ('PLAGL1', 'ENSTGUT00000011489', '1100000010000010'),
#  ('PLCB1', 'ENSTGUT00000006635', '1100100001'),
#  ('PLCE1', 'ENSTGUT00000009016', '1000001000101000'),
#  ('PLCL2', 'ENSTGUT00000003281', '1000000010000101'),
#  ('PLCXD3', 'ENSTGUT00000002315', '100010001100000'),
#  ('PLEKHA2', 'ENSTGUT00000005328', '10100011'),
#  ('PLEKHA3', 'ENSTGUT00000009584', '10000000010001001'),
#  ('PLEKHB1', 'ENSTGUT00000014031', '100000101000100000'),
#  ('PLEKHH2', 'ENSTGUT00000003803', '10100000000110000'),
#  ('PLEKHM3', 'ENSTGUT00000010499', '1100000001010000'),
#  ('PLK2', 'ENSTGUT00000002723', '100010000000110000'),
#  ('PLXDC2', 'ENSTGUT00000001275', '1010100000000010'),
#  ('PMEPA1', 'ENSTGUT00000008588', '100000011000010000'),
#  ('PMS2', 'ENSTGUT00000009156', '111000010000000'),
#  ('PNPT1', 'ENSTGUT00000007228', '101000000000100100'),
#  ('POFUT1', 'ENSTGUT00000018968', '100000000010001100'),
#  ('POLK', 'ENSTGUT00000006440', '100000001011'),
#  ('PPFIA1', 'ENSTGUT00000005726', '1011000000100'),
#  ('PPID', 'ENSTGUT00000005896', '1000010101000'),
#  ('PPIF', 'ENSTGUT00000006625', '10000001000100100'),
#  ('PPIG', 'ENSTGUT00000008238', '100000000011010000'),
#  ('PPME1', 'ENSTGUT00000014006', '10010000000001100'),
#  ('PPP1R16B', 'ENSTGUT00000004780', '10000100100000010'),
#  ('PPP1R7', 'ENSTGUT00000006500', '10100100000001'),
#  ('PPP1R9A', 'ENSTGUT00000001638', '10000010101000000'),
#  ('PPP2R5A', 'ENSTGUT00000003228', '1010000000001001'),
#  ('PPP3CA', 'ENSTGUT00000003715', '10110000100'),
#  ('PPP3CC', 'ENSTGUT00000015683', '10011010000000'),
#  ('PPP4R2', 'ENSTGUT00000010371', '11001000100000'),
#  ('PRKAG2', 'ENSTGUT00000000626', '10110000000000001'),
#  ('PRKAR2B', 'ENSTGUT00000003221', '1000001000000011'),
#  ('PRKCA', 'ENSTGUT00000004542', '110000010000000010'),
#  ('PRKCI', 'ENSTGUT00000011425', '10001001001000'),
#  ('PRKD1', 'ENSTGUT00000012306', '1101001'),
#  ('PRKD3', 'ENSTGUT00000008919', '1000000101000010'),
#  ('PSD3', 'ENSTGUT00000000311', '1000000100010100'),
#  ('PSME4', 'ENSTGUT00000007542', '11010010000000000'),
#  ('PTBP1', 'ENSTGUT00000000671', '101000100000001000'),
#  ('PTBP2', 'ENSTGUT00000005794', '1000100001000100'),
#  ('PTCHD1', 'ENSTGUT00000007643', '10000000100010001'),
#  ('PTPN12', 'ENSTGUT00000002837', '1010001010000'),
#  ('PTPN9', 'ENSTGUT00000003906', '1011100'),
#  ('PTPRM', 'ENSTGUT00000010377', '100100100010000000'),
#  ('PTPRZ1', 'ENSTGUT00000004787', '1010010100'),
#  ('PTS', 'ENSTGUT00000000301', '100000000000101010'),
#  ('PTTG1IP', 'ENSTGUT00000006274', '101001000010000'),
#  ('QDPR', 'ENSTGUT00000010112', '110110000'),
#  ('QKI', 'ENSTGUT00000009774', '10000001101'),
#  ('R3HDM1', 'ENSTGUT00000012261', '100010010000000100'),
#  ('RAB27A', 'ENSTGUT00000006769', '11000000000000110'),
#  ('RAB31', 'ENSTGUT00000010196', '1100100100000'),
#  ('RAB39B', 'ENSTGUT00000004189', '110010000010000'),
#  ('RAB3B', 'ENSTGUT00000009254', '10101000010000'),
#  ('RAB4A', 'ENSTGUT00000010497', '100001000000001001'),
#  ('RAB8B', 'ENSTGUT00000019232', '10000000011010'),
#  ('RALYL', 'ENSTGUT00000012180', '1001110000'),
#  ('RANBP2', 'ENSTGUT00000010030', '100010000100001000'),
#  ('RAP1B', 'ENSTGUT00000007011', '1010010000001'),
#  ('RAP1GDS1', 'ENSTGUT00000003403', '10011000000010000'),
#  ('RAPGEF4', 'ENSTGUT00000009004', '11000000010100000'),
#  ('RASD2', 'ENSTGUT00000011280', '1000011001000000'),
#  ('RASGEF1B', 'ENSTGUT00000003002', '1100010000000100'),
#  ('RASSF7', 'ENSTGUT00000010279', '110001000001'),
#  ('RASSF8', 'ENSTGUT00000012736', '100010000110'),
#  ('RB1CC1', 'ENSTGUT00000011432', '100100011000'),
#  ('RBFOX1', 'ENSTGUT00000004769', '1000110010000000'),
#  ('RBM18', 'ENSTGUT00000007066', '110000000101000'),
#  ('RCAN2', 'ENSTGUT00000013791', '10010010010'),
#  ('RCBTB1', 'ENSTGUT00000012655', '11000100000000001'),
#  ('RCBTB2', 'ENSTGUT00000012706', '100000010010100000'),
#  ('RCOR3', 'ENSTGUT00000003326', '100000111000000'),
#  ('RDX', 'ENSTGUT00000011731', '101010000001'),
#  ('REEP3', 'ENSTGUT00000005400', '101001010000000000'),
#  ('RELL1', 'ENSTGUT00000009516', '1000100000110000'),
#  ('RELN', 'ENSTGUT00000002991', '1000010100100000'),
#  ('RERE', 'ENSTGUT00000004099', '1001000001010'),
#  ('REV3L', 'ENSTGUT00000012524', '101000000001000001'),
#  ('RFK', 'ENSTGUT00000003646', '10000110100'),
#  ('RFX3', 'ENSTGUT00000005526', '1001000110'),
#  ('RFX7', 'ENSTGUT00000006588', '11101000000000000'),
#  ('RGS17', 'ENSTGUT00000011651', '1000000110001000'),
#  ('RGS4', 'ENSTGUT00000017655', '100001010100000'),
#  ('RGS7BP', 'ENSTGUT00000002892', '10000000100101000'),
#  ('RHOG', 'ENSTGUT00000016377', '10000011000001'),
#  ('RILPL2', 'ENSTGUT00000005568', '1001101000000000'),
#  ('RIOK1', 'ENSTGUT00000002435', '101000101'),
#  ('RIOK3', 'ENSTGUT00000010847', '100010000010000010'),
#  ('RIPK1', 'ENSTGUT00000002263', '10000110000000100'),
#  ('RIT1', 'ENSTGUT00000018092', '10100000000001010'),
#  ('RLF', 'ENSTGUT00000001504', '100001000000101'),
#  ('RMND5A', 'ENSTGUT00000011292', '100000100001001'),
#  ('RNF115', 'ENSTGUT00000004600', '10000010100100'),
#  ('RNF14', 'ENSTGUT00000000179', '100111000000000'),
#  ('RNF141', 'ENSTGUT00000008324', '110000101000'),
#  ('RNF146', 'ENSTGUT00000012260', '10010000110000000'),
#  ('RNF19B', 'ENSTGUT00000001392', '11000001000010000'),
#  ('RNF217', 'ENSTGUT00000012302', '1100100100000000'),
#  ('RNF38', 'ENSTGUT00000000103', '1001000011000000'),
#  ('RNGTT', 'ENSTGUT00000012942', '101000001010000000'),
#  ('RPL10A', 'ENSTGUT00000001820', '10000000001100010'),
#  ('RPL11', 'ENSTGUT00000001261', '10001001100000000'),
#  ('RPL19', 'ENSTGUT00000002274', '101110000000000000'),
#  ('RPL3', 'ENSTGUT00000010696', '11000000000011'),
#  ('RPL35A', 'ENSTGUT00000010099', '1100000010000010'),
#  ('RPLP0', 'ENSTGUT00000009872', '1100100001'),
#  ('RPLP2', 'ENSTGUT00000010227', '1000001000101000'),
#  ('RPN1', 'ENSTGUT00000008196', '1000000010000101'),
#  ('RPS2', 'ENSTGUT00000006944', '100010001100000'),
#  ('RPS21', 'ENSTGUT00000008057', '10100011'),
#  ('RPS25', 'ENSTGUT00000018948', '10000000010001001'),
#  ('RPS26', 'ENSTGUT00000017662', '100000101000100000'),
#  ('RRAGB', 'ENSTGUT00000005766', '10100000000110000'),
#  ('RRAGD', 'ENSTGUT00000012918', '1100000001010000'),
#  ('RSBN1', 'ENSTGUT00000001644', '100010000000110000'),
#  ('RSBN1L', 'ENSTGUT00000002820', '1010100000000010'),
#  ('RTF1', 'ENSTGUT00000011299', '100000011000010000'),
#  ('RUFY1', 'ENSTGUT00000001149', '111000010000000'),
#  ('RUFY3', 'ENSTGUT00000001722', '101000000000100100'),
#  ('SAMD12', 'ENSTGUT00000012845', '100000000010001100'),
#  ('SAMHD1', 'ENSTGUT00000003428', '100000001011'),
#  ('SATB2', 'ENSTGUT00000010931', '1011000000100'),
#  ('SAV1', 'ENSTGUT00000013704', '1000010101000'),
#  ('SCAF11', 'ENSTGUT00000006325', '10000001000100100'),
#  ('SCG2', 'ENSTGUT00000008220', '100000000011010000'),
#  ('SCOC', 'ENSTGUT00000002373', '10010000000001100'),
#  ('SCRG1', 'ENSTGUT00000006505', '10000100100000010'),
#  ('SDC3', 'ENSTGUT00000000833', '10100100000001'),
#  ('SDCBP', 'ENSTGUT00000011611', '10000010101000000'),
#  ('SEC23A', 'ENSTGUT00000012534', '1010000000001001'),
#  ('SEC61A1', 'ENSTGUT00000008307', '10110000100'),
#  ('SEMA4G', 'ENSTGUT00000010518', '10011010000000'),
#  ('SEMA6A', 'ENSTGUT00000018235', '11001000100000'),
#  ('SERPINE2', 'ENSTGUT00000008299', '10110000000000001'),
#  ('SERTAD4', 'ENSTGUT00000003351', '1000001000000011'),
#  ('SETX', 'ENSTGUT00000005317', '110000010000000010'),
#  ('SF3B4', 'ENSTGUT00000004646', '10001001001000'),
#  ('SF3B5', 'ENSTGUT00000011260', '1101001'),
#  ('SFXN3', 'ENSTGUT00000010484', '1000000101000010'),
#  ('SGK1', 'ENSTGUT00000012019', '1000000100010100'),
#  ('SGMS1', 'ENSTGUT00000005259', '11010010000000000'),
#  ('SH3BGRL3', 'ENSTGUT00000001075', '101000100000001000'),
#  ('SH3RF1', 'ENSTGUT00000006346', '1000100001000100'),
#  ('SHE', 'ENSTGUT00000004224', '10000000100010001'),
#  ('SHOC2', 'ENSTGUT00000011145', '1010001010000'),
#  ('SHPRH', 'ENSTGUT00000011227', '1011100'),
#  ('SIRT1', 'ENSTGUT00000003623', '100100100010000000'),
#  ('SKIL', 'ENSTGUT00000011412', '1010010100'),
#  ('SLAIN1', 'ENSTGUT00000013089', '100000000000101010'),
#  ('SLAIN2', 'ENSTGUT00000008417', '101001000010000'),
#  ('SLC10A7', 'ENSTGUT00000002751', '110110000'),
#  ('SLC12A2', 'ENSTGUT00000006887', '10000001101'),
#  ('SLC12A5', 'ENSTGUT00000006187', '100010010000000100'),
#  ('SLC15A4', 'ENSTGUT00000005042', '11000000000000110'),
#  ('SLC16A1', 'ENSTGUT00000018212', '1100100100000'),
#  ('SLC1A3', 'ENSTGUT00000002121', '110010000010000'),
#  ('SLC20A1', 'ENSTGUT00000003575', '10101000010000'),
#  ('SLC25A12', 'ENSTGUT00000008674', '100001000000001001'),
#  ('SLC25A16', 'ENSTGUT00000003898', '10000000011010'),
#  ('SLC25A17', 'ENSTGUT00000010507', '1001110000'),
#  ('SLC25A25', 'ENSTGUT00000003660', '100010000100001000'),
#  ('SLC25A26', 'ENSTGUT00000009999', '1010010000001'),
#  ('SLC25A46', 'ENSTGUT00000001022', '10011000000010000'),
#  ('SLC2A13', 'ENSTGUT00000003562', '11000000010100000'),
#  ('SLC30A1', 'ENSTGUT00000003290', '1000011001000000'),
#  ('SLC30A9', 'ENSTGUT00000008949', '1100010000000100'),
#  ('SLC32A1', 'ENSTGUT00000004714', '110001000001'),
#  ('SLC35A5', 'ENSTGUT00000013981', '100010000110'),
#  ('SLC35F5', 'ENSTGUT00000012164', '100100011000'),
#  ('SLC35G2', 'ENSTGUT00000007510', '1000110010000000'),
#  ('SLC39A11', 'ENSTGUT00000002999', '110000000101000'),
#  ('SLC41A1', 'ENSTGUT00000018199', '10010010010'),
#  ('SLC44A1', 'ENSTGUT00000000353', '11000100000000001'),
#  ('SLC5A3', 'ENSTGUT00000000472', '100000010010100000'),
#  ('SLC6A1', 'ENSTGUT00000004385', '100000111000000'),
#  ('SLC6A7', 'ENSTGUT00000000972', '101010000001'),
#  ('SLC8A3', 'ENSTGUT00000011885', '101001010000000000'),
#  ('SLC9A6', 'ENSTGUT00000003008', '1000100000110000'),
#  ('SLC9A7', 'ENSTGUT00000011049', '1000010100100000'),
#  ('SMAP1', 'ENSTGUT00000013239', '1001000001010'),
#  ('SMAP2', 'ENSTGUT00000018011', '101000000001000001'),
#  ('SMPD3', 'ENSTGUT00000007235', '10000110100'),
#  ('SNAP25', 'ENSTGUT00000006380', '1001000110'),
#  ('SNAPC3', 'ENSTGUT00000004728', '11101000000000000'),
#  ('SNRK', 'ENSTGUT00000004000', '1000000110001000'),
#  ('SNX13', 'ENSTGUT00000002710', '100001010100000'),
#  ('SNX18', 'ENSTGUT00000002542', '10000000100101000'),
#  ('SNX7', 'ENSTGUT00000005699', '10000011000001'),
#  ('SNX9', 'ENSTGUT00000011568', '1001101000000000'),
#  ('SOS1', 'ENSTGUT00000002153', '101000101'),
#  ('SOSTDC1', 'ENSTGUT00000002647', '100010000010000010'),
#  ('SP3', 'ENSTGUT00000009062', '10000110000000100'),
#  ('SPAG7', 'ENSTGUT00000015050', '10100000000001010'),
#  ('SPARC', 'ENSTGUT00000000802', '100001000000101'),
#  ('SPAST', 'ENSTGUT00000008855', '100000100001001'),
#  ('SPCS2', 'ENSTGUT00000014008', '10000010100100'),
#  ('SPIRE1', 'ENSTGUT00000010011', '100111000000000'),
#  ('SPOPL', 'ENSTGUT00000012333', '110000101000'),
#  ('SPRED1', 'ENSTGUT00000012236', '10010000110000000'),
#  ('SPRED2', 'ENSTGUT00000002440', '11000001000010000'),
#  ('SPRY2', 'ENSTGUT00000013112', '1100100100000000'),
#  ('SPTBN1', 'ENSTGUT00000007514', '1001000011000000'),
#  ('SPTY2D1', 'ENSTGUT00000009343', '101000001010000000'),
#  ('SRF', 'ENSTGUT00000004933', '10000000001100010'),
#  ('SRGAP1', 'ENSTGUT00000006672', '10001001100000000'),
#  ('SRPK1', 'ENSTGUT00000001725', '101110000000000000'),
#  ('SS18', 'ENSTGUT00000011040', '11000000000011'),
#  ('SS18L1', 'ENSTGUT00000008180', '1100000010000010'),
#  ('ST8SIA3', 'ENSTGUT00000018189', '1100100001'),
#  ('STIM2', 'ENSTGUT00000009569', '1000001000101000'),
#  ('STK24', 'ENSTGUT00000011522', '1000000010000101'),
#  ('STOML2', 'ENSTGUT00000001848', '100010001100000'),
#  ('STRN', 'ENSTGUT00000009085', '10100011'),
#  ('SUCLA2', 'ENSTGUT00000012755', '10000000010001001'),
#  ('SUGT1', 'ENSTGUT00000012954', '100000101000100000'),
#  ('SULF2', 'ENSTGUT00000009356', '10100000000110000'),
#  ('SUMF2', 'ENSTGUT00000005349', '1100000001010000'),
#  ('SUN2', 'ENSTGUT00000010774', '100010000000110000'),
#  ('SV2B', 'ENSTGUT00000008813', '1010100000000010'),
#  ('SYAP1', 'ENSTGUT00000008200', '100000011000010000'),
#  ('SYNDIG1L', 'ENSTGUT00000012628', '111000010000000'),
#  ('SYNJ1', 'ENSTGUT00000014003', '101000000000100100'),
#  ('SYT2', 'ENSTGUT00000001358', '100000000010001100'),
#  ('TAC1', 'ENSTGUT00000001719', '100000001011'),
#  ('TAOK1', 'ENSTGUT00000006569', '1011000000100'),
#  ('TBC1D12', 'ENSTGUT00000008936', '1000010101000'),
#  ('TBC1D4', 'ENSTGUT00000013047', '10000001000100100'),
#  ('TBC1D9B', 'ENSTGUT00000001056', '100000000011010000'),
#  ('TBK1', 'ENSTGUT00000006759', '10010000000001100'),
#  ('TBPL1', 'ENSTGUT00000012029', '10000100100000010'),
#  ('TBR1', 'ENSTGUT00000006960', '10100100000001'),
#  ('TCF20', 'ENSTGUT00000010076', '10000010101000000'),
#  ('TEF', 'ENSTGUT00000010366', '1010000000001001'),
#  ('TERF2', 'ENSTGUT00000008423', '10110000100'),
#  ('TET2', 'ENSTGUT00000003939', '10011010000000'),
#  ('TFEB', 'ENSTGUT00000018117', '11001000100000'),
#  ('TFRC', 'ENSTGUT00000009948', '10110000000000001'),
#  ('TIAL1', 'ENSTGUT00000011628', '1000001000000011'),
#  ('TIPARP', 'ENSTGUT00000018133', '110000010000000010'),
#  ('TIPRL', 'ENSTGUT00000013993', '10001001001000'),
#  ('TLE4', 'ENSTGUT00000003504', '1101001'),
#  ('TLK2', 'ENSTGUT00000003233', '1000000101000010'),
#  ('TM9SF4', 'ENSTGUT00000006797', '1000000100010100'),
#  ('TMCC1', 'ENSTGUT00000011005', '11010010000000000'),
#  ('TMED5', 'ENSTGUT00000006185', '101000100000001000'),
#  ('TMEFF2', 'ENSTGUT00000011163', '1000100001000100'),
#  ('TMEM120B', 'ENSTGUT00000006306', '10000000100010001'),
#  ('TMEM123', 'ENSTGUT00000013269', '1010001010000'),
#  ('TMEM130', 'ENSTGUT00000008971', '1011100'),
#  ('TMEM163', 'ENSTGUT00000012199', '100100100010000000'),
#  ('TMEM167A', 'ENSTGUT00000007193', '1010010100'),
#  ('TMEM170B', 'ENSTGUT00000006020', '100000000000101010'),
#  ('TMEM206', 'ENSTGUT00000003183', '101001000010000'),
#  ('TMEM39A', 'ENSTGUT00000013949', '110110000'),
#  ('TMEM63A', 'ENSTGUT00000004355', '10000001101'),
#  ('TMEM63B', 'ENSTGUT00000008464', '100010010000000100'),
#  ('TMEM65', 'ENSTGUT00000012984', '11000000000000110'),
#  ('TMX3', 'ENSTGUT00000009702', '1100100100000'),
#  ('TMX4', 'ENSTGUT00000006652', '110010000010000'),
#  ('TNIK', 'ENSTGUT00000011372', '10101000010000'),
#  ('TNKS', 'ENSTGUT00000005081', '100001000000001001'),
#  ('TNPO1', 'ENSTGUT00000005983', '10000000011010'),
#  ('TNRC6A', 'ENSTGUT00000006407', '1001110000'),
#  ('TNS3', 'ENSTGUT00000007411', '100010000100001000'),
#  ('TOMM70', 'ENSTGUT00000014197', '1010010000001'),
#  ('TPM1', 'ENSTGUT00000005229', '10011000000010000'),
#  ('TRAF3', 'ENSTGUT00000013353', '11000000010100000'),
#  ('TRAK1', 'ENSTGUT00000004932', '1000011001000000'),
#  ('TRERF1', 'ENSTGUT00000003387', '1100010000000100'),
#  ('TRIM2', 'ENSTGUT00000005311', '110001000001'),
#  ('TRIM23', 'ENSTGUT00000002966', '100010000110'),
#  ('TRMT11', 'ENSTGUT00000012270', '100100011000'),
#  ('TTC19', 'ENSTGUT00000006938', '1000110010000000'),
#  ('TTC7B', 'ENSTGUT00000013025', '110000000101000'),
#  ('TTC9', 'ENSTGUT00000011841', '10010010010'),
#  ('TXLNG', 'ENSTGUT00000008189', '11000100000000001'),
#  ('TXNDC16', 'ENSTGUT00000013658', '100000010010100000'),
#  ('TXNDC5', 'ENSTGUT00000002458', '100000111000000'),
#  ('UAP1', 'ENSTGUT00000017818', '101010000001'),
#  ('UBE2K', 'ENSTGUT00000009159', '101001010000000000'),
#  ('UBE2Q1', 'ENSTGUT00000004248', '1000100000110000'),
#  ('UBE2QL1', 'ENSTGUT00000008133', '1000010100100000'),
#  ('UBE3C', 'ENSTGUT00000000739', '1001000001010'),
#  ('UBN2', 'ENSTGUT00000009985', '101000000001000001'),
#  ('UBR1', 'ENSTGUT00000011655', '10000110100'),
#  ('UBR5', 'ENSTGUT00000012618', '1001000110'),
#  ('UBXN7', 'ENSTGUT00000006111', '11101000000000000'),
#  ('UCHL1', 'ENSTGUT00000009024', '1000000110001000'),
#  ('UCHL5', 'ENSTGUT00000004282', '100001010100000'),
#  ('UCKL1', 'ENSTGUT00000007458', '10000000100101000'),
#  ('UGCG', 'ENSTGUT00000001324', '10000011000001'),
#  ('UGDH', 'ENSTGUT00000009195', '1001101000000000'),
#  ('UGT8', 'ENSTGUT00000001919', '101000101'),
#  ('UIMC1', 'ENSTGUT00000000462', '100010000010000010'),
#  ('UPF1', 'ENSTGUT00000001097', '10000110000000100'),
#  ('UROD', 'ENSTGUT00000008178', '10100000000001010'),
#  ('USE1', 'ENSTGUT00000000465', '100001000000101'),
#  ('USP15', 'ENSTGUT00000006546', '100000100001001'),
#  ('USP28', 'ENSTGUT00000000107', '10000010100100'),
#  ('USP3', 'ENSTGUT00000003311', '100111000000000'),
#  ('USP4', 'ENSTGUT00000006950', '110000101000'),
#  ('USP53', 'ENSTGUT00000001967', '10010000110000000'),
#  ('USP6NL', 'ENSTGUT00000002234', '11000001000010000'),
#  ('VAMP1', 'ENSTGUT00000013891', '1100100100000000'),
#  ('VAMP4', 'ENSTGUT00000017967', '1001000011000000'),
#  ('VANGL1', 'ENSTGUT00000013946', '101000001010000000'),
#  ('VANGL2', 'ENSTGUT00000004574', '10000000001100010'),
#  ('VAPB', 'ENSTGUT00000008528', '10001001100000000'),
#  ('VAT1L', 'ENSTGUT00000009523', '101110000000000000'),
#  ('VBP1', 'ENSTGUT00000004184', '11000000000011'),
#  ('VCAN', 'ENSTGUT00000007174', '1100000010000010'),
#  ('VEGFC', 'ENSTGUT00000006690', '1100100001'),
#  ('VMA21', 'ENSTGUT00000004739', '1000001000101000'),
#  ('VPS13A', 'ENSTGUT00000003618', '1000000010000101'),
#  ('VPS13B', 'ENSTGUT00000012538', '100010001100000'),
#  ('VPS26A', 'ENSTGUT00000004052', '10100011'),
#  ('VPS26B', 'ENSTGUT00000000676', '10000000010001001'),
#  ('VPS4B', 'ENSTGUT00000002138', '100000101000100000'),
#  ('VRK1', 'ENSTGUT00000013228', '10100000000110000'),
#  ('VSTM2A', 'ENSTGUT00000008321', '1100000001010000'),
#  ('WARS', 'ENSTGUT00000013293', '100010000000110000'),
#  ('WDR19', 'ENSTGUT00000009352', '1010100000000010'),
#  ('WDR36', 'ENSTGUT00000001032', '100000011000010000'),
#  ('WDR6', 'ENSTGUT00000009428', '111000010000000'),
#  ('WDR70', 'ENSTGUT00000002195', '101000000000100100'),
#  ('WDTC1', 'ENSTGUT00000001007', '100000000010001100'),
#  ('WIPF2', 'ENSTGUT00000002378', '100000001011'),
#  ('WNK1', 'ENSTGUT00000013141', '1011000000100'),
#  ('WWP2', 'ENSTGUT00000008503', '1000010101000'),
#  ('XBP1', 'ENSTGUT00000008269', '10000001000100100'),
#  ('XPO5', 'ENSTGUT00000009571', '100000000011010000'),
#  ('YAF2', 'ENSTGUT00000006045', '10010000000001100'),
#  ('YARS', 'ENSTGUT00000001404', '10000100100000010'),
#  ('YPEL2', 'ENSTGUT00000007809', '10100100000001'),
#  ('YPEL5', 'ENSTGUT00000005618', '10000010101000000'),
#  ('YTHDF3', 'ENSTGUT00000011716', '1010000000001001'),
#  ('ZADH2', 'ENSTGUT00000009488', '10110000100'),
#  ('ZBTB1', 'ENSTGUT00000013466', '10011010000000'),
#  ('ZBTB10', 'ENSTGUT00000012133', '11001000100000'),
#  ('ZBTB33', 'ENSTGUT00000018848', '10110000000000001'),
#  ('ZBTB38', 'ENSTGUT00000008715', '1000001000000011'),
#  ('ZC3H12C', 'ENSTGUT00000011717', '110000010000000010'),
#  ('ZDHHC2', 'ENSTGUT00000007568', '10001001001000'),
#  ('ZDHHC5', 'ENSTGUT00000007308', '1101001'),
#  ('ZEB1', 'ENSTGUT00000001060', '1000000101000010'),
#  ('ZEB2', 'ENSTGUT00000012405', '1000000100010100'),
#  ('ZFC3H1', 'ENSTGUT00000007525', '11010010000000000'),
#  ('ZFHX4', 'ENSTGUT00000012093', '101000100000001000'),
#  ('ZFPM2', 'ENSTGUT00000012694', '1000100001000100'),
#  ('ZFYVE9', 'ENSTGUT00000009310', '10000000100010001'),
#  ('ZHX1', 'ENSTGUT00000012941', '1010001010000'),
#  ('ZNF462', 'ENSTGUT00000006600', '1011100'),
#  ('ZNF644', 'ENSTGUT00000006421', '100100100010000000'),
#  ('ZNF652', 'ENSTGUT00000003602', '1010010100'),
#  ('ZNF827', 'ENSTGUT00000002771', '100000000000101010'),
#  ('ZNFX1', 'ENSTGUT00000005859', '101001000010000'),
#  ('ZNHIT6', 'ENSTGUT00000006659', '110110000'),
#  ...]

# %% [markdown]
# Now design probes
# parse_merfish_oligos to add results to spreadsheet
# Filter genes with low probes and repeat
# Decide on final gene list and run agian

# %%
def parse_merfish_oligos(fname, counts_df = None,
                         counts_df_column='FPKM', tid_column='transcript_id'):
    """
    Bit hacky - should refactor and figure out how to handle missing isoform specificity info.
    """
    from Bio import SeqIO
    import pandas as pd
    df = pd.DataFrame(columns=['experiemnt', 'pleft', 'ro1', 'ro2', 'ro3', 
                               'pright', 'seq', 'gene', 'tid', 
                              'start', 'length', 'gc', 'tm', 'specicity'])
    readout_dict = {}
    oligos = SeqIO.FastaIO.SimpleFastaParser(open(fname, 'r'))
    rows = []
    fpkms = []
    for header, seq in oligos:
        fields = header.split(' ')
        experiment = str(fields[0])
        primer_left = str(fields[1])
        primer_seqL = seq[:20]
        primer_seqR = seq[-20:]
        readout1 = str(fields[2])
        readout_dict[readout1] = seq[20+1:20+1+20]
        isoSpecificity = 1
        # Order is different if Readouts are RO1/RO2 - encoding - RO3 vs RO1 - encoding - RO2/RO3
        # Check with if statement and handle accordingly.
        if '__' not in fields[3]:
            readout2 = str(fields[3])
            encoding = str(fields[4])
            readout3 = fields[5]
            ro2_start_idx = 41
            ro3_start_idx = 92
            readout_dict[readout3] = seq[20+20+20+1+30+1:20+1+20+20+30+1+20]
            readout_dict[readout2] = seq[20+1+20:20+1+20+20]
            primer_right = fields[6]
            gene, tid, start, length, gc, tm, specificity  = encoding.split('__')


#             gene, tid, start, length, gc, tm, specificity, isoSpecificity  = encoding.split('__')
            encoding_region = seq[20+1+20+20:20+20+1+20+30]
        else:
            encoding = fields[3]
#             isoSpecificity = fields[4]
            readout2 = fields[4]
            readout3 = fields[5]
            ro2_start_idx = 72
            ro3_start_idx = 92
            readout_dict[readout2] = seq[20+2+20+30:20+20+30+20+2]
            readout_dict[readout3] = seq[20+2+20+30+20:20+20+30+20+20+2]
            primer_right = fields[6]
            gene, tid, start, length, gc, tm, specificity  = encoding.split('__')
#             gene, tid, start, length, gc, tm, specificity, isoSpecificity  = encoding.split('__')
        # IMPLEMENT READOUT DICT In If Else
            encoding_region = seq[20+1+20:20+1+20+30]
        
        rows.append([experiment, primer_seqL, readout1, readout2, readout3, 
                       primer_seqR, encoding_region, seq, gene, tid, start,
                     length, gc, tm, specificity, isoSpecificity, header])
    df = pd.DataFrame(rows, columns=['experiment', 'pleft', 'ro1', 'ro2', 'ro3', 
                               'pright', 'encodingRegion', 'seq', 'gene', 'tid', 
                              'start', 'length', 'gc', 'tm', 'specificity', 'isoSpecificity', 'header'])
    df = df.drop_duplicates(subset=['gene', 'encodingRegion'])
#     if isinstance(counts_df, pd.DataFrame):
#         for tid in df.tid.unique():
#             fpkm = counts_df[counts_df[tid_column]==tid][counts_df_column]
#             tid_idx = df[df.tid==tid].index
#             for i in tid_idx:
#                 df.set_value(i, counts_df_column, fpkm.values[0])
#     df = df.convert_objects(convert_numeric=True)
#     df.sort_values(['gene', 'specificity', 'isoSpecificity'], ascending=False, inplace=True)
#     df['iso_off_spots'] = (df[counts_df_column] - df['isoSpecificity']*df[counts_df_column])/df['isoSpecificity']
#     df['gene_off_spots'] = (df[counts_df_column] - df['specificity']*df[counts_df_column])/df['specificity']
#     df = df.drop_duplicates('tid')
    return df, primer_seqL, primer_seqR, readout_dict

def trim_oligos_to_fit(oligo_df, multi_transcripts_cutoff = 148, min_oligos=48):
    df2 = oligo_df.copy()
    c = Counter(df2.gene)
    high_count = {}
    for g, count in c.items():
        if count < min_oligos:
            print(g, count)
#             c.pop(g)
            if g not in ['SNAI2', 'SNAI1', 'ORAI1', 'P2RY11', 'INPP1', 'ACTA2', 'PICK1']:
                df2.drop(df2[df2.gene==g].index, inplace=True)
#         if count>multi_transcripts_cutoff:
#             high_count[g] = count
#             ixes = list(df2[df2.gene==g].index)
#             ixes = np.random.choice(ixes, size=multi_transcripts_cutoff, replace=False)
#             df2.drop(ixes, inplace=True)
    return df2

# def balance_readouts(df, per_tid=64, fa_out='mergos.fa'):
#     from itertools import repeat
#     tids = df.groupby(group)
#     f = open(fa_out, 'w')
#     new_df = pd.DataFrame()
#     counters = []
#     for name, group in tids:
#         r_used = pd.unique(np.concatenate((group.ro1.unique(),group.ro2.unique(),group.ro3.unique())))
        
def balance_readouts(df, primersL, primersR, readouts, per_tid=64, group='tid',
                     fa_out='python_mergos.fa', sep='__'):
    verbose=False
    from itertools import repeat
    tids = df.groupby(group)
    f = open(fa_out, 'w')
    new_df = pd.DataFrame()
    counters = {}
    for name, group in tids:
        counts = Counter()
        r_used = pd.unique(np.concatenate((group.ro1.unique(),group.ro2.unique(),group.ro3.unique())))
        r_used = np.concatenate(list(repeat(r_used, 1000)))
        oligo_index = group.index.tolist()
        np.random.shuffle(oligo_index)
        oligo_index = oligo_index[:per_tid]
        base_idx = 0
        c = Counter()
        for i, idx in enumerate(oligo_index):
            ro1_seq = ''
            ro2_seq = ''
            ro3_seq = ''
            oligo = ''
            ro1=''
            ro2=''
            ro3=''
#             try:
            ro1_seq = readouts[r_used[base_idx]]
            ro1 = r_used[base_idx]
        
            ro2_seq = readouts[r_used[base_idx+1]]
            ro2 = r_used[base_idx+1]
            
            ro3_seq = readouts[r_used[base_idx+2]]
            ro3 = r_used[base_idx+2]
            
            c.update([ro1, ro2, ro3])
            row = group.loc[idx]
            rand = np.random.randint(0, high=2)
            if (ro1 not in r_used) or (ro2 not in r_used) or (ro3 not in r_used):
                print(row)
            if rand:
                oligo = row.pleft+'A'+ro1_seq+ro2_seq+row.encodingRegion+'A'+ro3_seq+row.pright

#                     row.set_value(idx, 'oligo', row.pleft+row.ro1+row.ro2+'A'+row.encodingRegion+'A'+row.ro3+row.pright)
            else:
                oligo = row.pleft+'A'+ro1_seq+row.encodingRegion+'A'+ro2_seq+ro3_seq+row.pright
            if (len(row.encodingRegion) != 30) or (len(ro1_seq) != 20):

                print(len(row.encodingRegion), len(ro1_seq))
#                     row.set_value(idx, 'oligo', row.pleft+row.ro1+'A'+row.encodingRegion+'A'+row.ro2+row.ro3+row.pright)
            header = ">"+row.gene+sep+row.tid+sep+str(row.start)+sep+ro1+sep+ro2+sep+ro3+sep+row.experiment+'\n'
            f.write(header)
            f.write(oligo+'\n')
            base_idx += 3
#             except Exception as e:
#                 print(e)
#                 continue
        counters[name] = c
        if len(c.keys())>4:
            print(name)
    f.close()
    return new_df, fa_out, counters

# %%
# update spreadsheet with Probe design data
# Sequences, FPKM, number of probes
df = parse_merfish_oligos('/bigstore/GeneralStorage/Rob/merfish/MERFISH_analysis-master/mouse/Cornea_Wound/Cornea_Wound_oligos.fasta')[0]
from collections import Counter
counts = Counter(df.gene)
num_oligos = expression_worksheet.range('E2:E189')
gnames = expression_worksheet.range('A2:A189')
for k, v in counts.items():
    idx = [i for i, g in enumerate(gnames) if g.value==k][0]
    num_oligos[idx].value = v
expression_worksheet.update_cells(num_oligos)
# Out:
# {'spreadsheetId': '11MMvEY4s8oUIGf5kyoA4QOKs-Br2myyNooNmSO7-nEU',
#  'updatedCells': 188,
#  'updatedColumns': 1,
#  'updatedRange': 'Sheet1!E2:E189',
#  'updatedRows': 188}

# %%
gene_list = []
for i in range(len(gene_annotations)):
    gene_list.append(gene_annotations[i][0])
