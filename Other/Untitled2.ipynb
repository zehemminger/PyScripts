# %%
from fish_helpers import *
beads = pickle.load(open('/hybedata/Images/Robert/TBI_v2/sham_m3_slide4_2019Nov04/results/beads.pkl','rb'))

# %%
beads.keys()
# Out:
# dict_keys(['Pos176', 'Pos174', 'Pos50', 'Pos182', 'Pos291', 'Pos14', 'Pos267', 'Pos11', 'Pos177', 'Pos78', 'Pos300', 'Pos124', 'Pos2', 'Pos69', 'Pos257', 'Pos261', 'Pos126', 'Pos30', 'Pos233', 'Pos236', 'Pos21', 'Pos80', 'Pos128', 'Pos74', 'Pos17', 'Pos28', 'Pos67', 'Pos72', 'Pos52', 'Pos276', 'Pos274', 'Pos130', 'Pos6', 'Pos243', 'Pos297', 'Pos48', 'Pos56', 'Pos133', 'Pos192', 'Pos250', 'Pos153', 'Pos86', 'Pos240', 'Pos101', 'Pos234', 'Pos229', 'Pos216', 'Pos68', 'Pos109', 'Pos167', 'Pos278', 'Pos212', 'Pos81', 'Pos206', 'Pos61', 'Pos59', 'Pos110', 'Pos3', 'Pos39', 'Pos159', 'Pos140', 'Pos148', 'Pos16', 'Pos82', 'Pos58', 'Pos232', 'Pos141', 'Pos137', 'Pos117', 'Pos247', 'Pos189', 'Pos285', 'Pos238', 'Pos44', 'Pos91', 'Pos198', 'Pos224', 'Pos152', 'Pos190', 'Pos163', 'Pos170', 'Pos10', 'Pos146', 'Pos301', 'Pos269', 'Pos210', 'Pos22', 'Pos231', 'Pos62', 'Pos139', 'Pos36', 'Pos288', 'Pos293', 'Pos164', 'Pos286', 'Pos118', 'Pos203', 'Pos222', 'Pos45', 'Pos19', 'Pos204', 'Pos225', 'Pos11
# ...

# %%
beads['Pos176'].keys()
# Out:
# dict_keys(['hybe1', 'hybe2', 'hybe3', 'hybe4', 'hybe5', 'hybe6', 'hybe7', 'hybe8', 'hybe9', 'nucstain'])

# %%
x
# Out:
# array([[2025.4,  960.6,   11.2],
#        [2018. ,  977.8,   10.6],
#        [1982.4, 1372.8,   11.8],
#        [1880. ,  842.4,   10.2],
#        [1862.8,  379.6,   10.2],
#        [1840.4,  187.6,   11.2],
#        [1815.6,  630.8,    9. ],
#        [1808.8,   72. ,    9.2],
#        [1771.2, 1522. ,   13.8],
#        [1770. ,  892.4,   12.6],
#        [1768. , 1844.2,   14.2],
#        [1762.6,  703.8,    8.2],
#        [1760. , 1456.4,   14.2],
#        [1760. , 1355.6,    8.2],
#        [1744.2,  555.2,    9.8],
#        [1743.2, 1327.6,    9.8],
#        [1717.4, 1056.4,   10.2],
#        [1717.8,  413.4,    8.6],
#        [1713. , 1472.2,    8.8],
#        [1708.8, 1023.6,    8. ],
#        [1694.6,  860.8,   12.8],
#        [1681.8,  979.2,   11.6],
#        [1680.4, 1435.4,   11.8],
#        [1675. , 1456.8,   11.6],
#        [1654.4,  596.4,   10.6],
#        [1652.6, 1079.4,    8.2],
#        [1634. , 1610.2,   10.4],
#        [1627. ,  383.6,    9.2],
# ...

# %%
x = np.stack(beads['Pos176']['hybe1'])
plt.figure(figsize=[10,10])
plt.scatter(x[:,0],x[:,1],c=x[:,2])

# %%
x = np.stack(beads['Pos176']['hybe2'])
plt.figure(figsize=[10,10])
plt.scatter(x[:,0],x[:,1],c=x[:,2])

# %%
plt.figure(figsize=[10,10])
x = np.stack(beads['Pos176']['hybe1'])
plt.scatter(x[:,0],x[:,1],c='b',alpha=0.5)
x = np.stack(beads['Pos176']['hybe2'])
plt.scatter(x[:,0],x[:,1],c='r',alpha=0.5)
plt.xlim([1100,1500])
plt.ylim([1300,1400])
plt.show()
