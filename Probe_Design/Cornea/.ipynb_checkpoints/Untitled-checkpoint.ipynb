# %%
import pandas as pd
fpkm = pd.read_csv('/bigstore/binfo/mouse/Cornea_FPKM.csv')
fpkm
# Out:
#              transcript_id class_code nearest_ref_id             gene_id  \
# 0       ENSMUST00000182774          -              -  ENSMUSG00000098104
# 1       ENSMUST00000193443          -              -  ENSMUSG00000102175
# 2       ENSMUST00000157708          -              -  ENSMUSG00000088333
# 3       ENSMUST00000195771          -              -  ENSMUSG00000104328
# 4       ENSMUST00000082908          -              -  ENSMUSG00000064842
# 5       ENSMUST00000193244          -              -  ENSMUSG00000102348
# 6       ENSMUST00000193812          -              -  ENSMUSG00000102693
# 7       ENSMUST00000193889          -              -  ENSMUSG00000103003
# 8       ENSMUST00000194643          -              -  ENSMUSG00000102343
# 9       ENSMUST00000192427          -              -  ENSMUSG00000102343
# 10      ENSMUST00000194454          -              -  ENSMUSG00000102592
# 11      ENSMUST00000192738          -              -  ENSMUSG00000102735
# ...

# %%
fpkm[fpkm.gene_id=='ENSMUSG00000026728'].sort_values(by=['FPKM'],ascending=False)
# Out:
#            transcript_id class_code nearest_ref_id             gene_id  \
# 9044  ENSMUST00000148248          -              -  ENSMUSG00000026728
# 9040  ENSMUST00000028062          -              -  ENSMUSG00000026728
# 9041  ENSMUST00000193675          -              -  ENSMUSG00000026728
# 9042  ENSMUST00000155605          -              -  ENSMUSG00000026728
# 9043  ENSMUST00000191615          -              -  ENSMUSG00000026728
# 9039  ENSMUST00000141365          -              -  ENSMUSG00000026728
#
#      gene_short_name tss_id                   locus  length      coverage  \
# 9044             Vim      -  chr2:13579368-13582478     535  4.341940e+02
# 9040             Vim      -  chr2:13573951-13582826    2193  1.683770e+02
# 9041             Vim      -  chr2:13574280-13582825    1777  1.211980e+02
# 9042             Vim      -  chr2:13574321-13578604     926  5.133300e-01
# 9043             Vim      -  chr2:13574522-13577448    2926  1.787880e-01
# ...
